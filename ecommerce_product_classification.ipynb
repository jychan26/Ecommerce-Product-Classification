# %% [markdown]
# # Introduction
#
# This code is expected to run on Colab, and should be run from top to bottom.
#
# The user is also expected to upload `uw-cs480-winter23.zip` when running the code in the *Upload files in Google Colab* section.
#
# Note there is a risk of Colab crashing due to reaching RAM limit. If so, please uncomment and run `torch.save` and `torch.load` as well when running the notebook so that you won't lose all progress when running the notebook.

# %% [markdown]
# ---
# # Report
#
# This code can be divided into 5 parts:
# 1. Load Data
# 2. Combine Text & Categorical Data
# 3. CNN Models
# 4. Weighted Majority Vote
# 5. Download Predictions
#
# ***Note:***
# - Categorical columns refer to `['gender', 'baseColour', 'season', 'usage']`.
# - Text column refers to `noisyTextDescription`.
#
# ***Part 2: Combine Text & Categorical Data***
#
# Text and categorical data are combined as inputs before getting fed into linear support vector classifiers (`LinearSVC` and `SGDClassifier`). Linear SVCs are generally regarded as one of the best text classification algorithms, hence our decision to use these models.
#
# Preprocessing:
# - Categorical columns: one-hot encoding on the categorical data (`OneHotEncoder`).
# - Text column: computed the normalized term frequency matrix (`CountVectorizer` followed by `TfidfTransformer`).
#   - The parameters used for `CountVectorizer` enable accents removal, lowercasing, word tokenizing, stopwords removal, and filtering of tokens of 2 or more alphanumeric characters (in addition to building our own dictionary according to the train dataset).
#   - `TdidfTransformer` is used to transform our count matrix (aka `CountVectorizer` output) to a normalized term frequency representation (`use_idf=False`).
#
# Modeling & Bagging:
#
# The preprocessed categorical and text columns are concatenated together before getting fed into our selected models to achieve 81-82% validation accuracy. This accuracy is further improved by 0.5-1% with bagging on each model. To ensure our SVCs are weak learners and to decrease computation time, each model is configured to `max_iter=5`.
#
# This was a great improvement as only fitting the models on categorical data yieled 55% validation accuracy, while only fitting on text data yieled 78-79% validation accuracy. In addition, adding the categorical columns allow us to somewhat mitigate the noise from the text data, leading to a better performance.
#
# ***Part 3: CNN Models***
#
# In part 3, I used 5 convolutional neural networks - each CNN is fed with different inputs. The CNN architecture for all 5 models are the same except for the first hidden fully connected layer, which will be explained in detail at the bottom.
#
# The CNN architecture consists of 3 convolutional blocks - each block consists of 2 3x3 convolutional layers followed by a single 2x2 pooling layer (note the second convolutional block has a pooling layer of 3x2 to avoid rounding as our image sizes are 60x80). A dropout probability of 0.25 is applied after each max pooling layer and a dropout probability of 0.5 is applied after the first hidden fully connected layer.
#
# For all CNNs below, the images are treated the same as follows:
# - Images: The images are transformed into tensors before getting normalized using the mean and standard deviation of the entire train dataset.
#
# * CNN1 - images & categorical data:
#   - Categorical columns: As all the categorical columns contain string values, I lowercased and joined all the strings for each training instance (e.g. `sandal men tan summer`) before proceeding to get the text embedding of each sentence using the pretrained 25-dimensional GloVe embedding via `zeugma` package.
#
# * CNN2 - images & categorical data:
#   - Categorical columns: one-hot encoding on the categorical data (`OneHotEncoder`).
#
# * CNN3 - images only.
#
# * CNN4 - images, categorical and text data:
#   - Categorical columns: one-hot encoding on the categorical data (`OneHotEncoder`).
#   - Text column: computed the normalized term frequency matrix (`CountVectorizer` followed by `TfidfTransformer`), as above.
#
# * CNN5 - images, categorical and text data:
#   - Categorical columns: lowercased and joined all the strings for each training instance (e.g. `sandal men tan summer`) before proceeding to get the text embedding of each sentence using the pretrained 25-dimensional GloVe embedding via `zeugma` package.
#   - Text column: computed the normalized term frequency matrix (`CountVectorizer` followed by `TfidfTransformer`), as above.
#
# In order to make use of text/categorical data in CNN1, CNN2, CNN4, and CNN5, we appended the extra data into the first fully connected hidden layer, e.g. CNN3: `self.fc1 = nn.Linear(128*5*10,1024)` vs CNN5: `self.fc1 = nn.Linear(128*5*10+8462,1024)` where there are 8462 extra nodes to account for both categorical and text inputs.
#
#
# ***Model Validation Performances***:
# - Bagged LinearSVC: 82.80%.
# - Bagged SGDClassifier: 82.28%.
# - CNN1: 83.65% (best performing epoch: 11).
# - CNN2: 84.13% (best performing epoch: 7).
# - CNN3: 80.62% (best performing epoch: 7).
# - CNN4: 90.29% (best performing epoch: 7).
# - CNN5: 89.07% (best performing epoch: 7).
#
# For CNN models, the best performing epoch is determined by the lowest validation loss, which we will use when training the models on the full training set.
#
# ***Part 4: Weighted Majority Vote***
#
# As models like SVCs cannot predict probability on Scikit-Learn, we instead resort to using the normalized validation accuracies as weights to do a weighted majority vote. For example, CNN3 has the lowest weight while CNN4 has the highest weight. Using this weighted approach allows us to generalize better while providing less weights to models with noisy predictions (like CNN3).
#
# Using this method, we were able to achieve a 91% validation accuracy despite having only 2 models with ~90% validation accuracy.

# %% [markdown]
# ---
# # Upload files in Google Colab
# Upload uw-cs480-winter23.zip file. Run the following command to unzip the file.

# %%
from google.colab import files
uploaded = files.upload()
# %ls

# !unzip uw-cs480-winter23.zip
# !ls
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: noisy-images/noisy-images/58012.jpg
#   inflating: noisy-images/noisy-images/58013.jpg
#   inflating: noisy-images/noisy-images/58014.jpg
#   inflating: noisy-images/noisy-images/58015.jpg
#   inflating: noisy-images/noisy-images/58016.jpg
#   inflating: noisy-images/noisy-images/58017.jpg
#   inflating: noisy-images/noisy-images/58018.jpg
#   inflating: noisy-images/noisy-images/5802.jpg
#   inflating: noisy-images/noisy-images/58020.jpg
#   inflating: noisy-images/noisy-images/58022.jpg
#   inflating: noisy-images/noisy-images/58023.jpg
#   inflating: noisy-images/noisy-images/58024.jpg
#   inflating: noisy-images/noisy-images/58027.jpg
#   inflating: noisy-images/noisy-images/58028.jpg
#   inflating: noisy-images/noisy-images/5803.jpg
#   inflating: noisy-images/noisy-images/58030.jpg
#   inflating: noisy-images/noisy-images/58032.jpg
#   inflating: noisy-images/noisy-images/58035.jpg
#   inflating: noisy-images/noisy-images/58037.jpg
#   inflating: noisy-images/noisy-images/58039.jpg
#   inflating: noisy-images/noisy-images/5804.jpg
#   inflating: noisy-images/noisy-images/58041.jpg
#   inflating: noisy-images/noisy-images/58042.jpg
#   inflating: noisy-images/noisy-images/58044.jpg
#   inflating: noisy-images/noisy-images/58045.jpg
#   inflating: noisy-images/noisy-images/58046.jpg
#   inflating: noisy-images/noisy-images/58049.jpg
#   inflating: noisy-images/noisy-images/5805.jpg
#   inflating: noisy-images/noisy-images/58050.jpg
#   inflating: noisy-images/noisy-images/58051.jpg
#   inflating: noisy-images/noisy-images/58052.jpg
#   inflating: noisy-images/noisy-images/58053.jpg
#   inflating: noisy-images/noisy-images/58057.jpg
#   inflating: noisy-images/noisy-images/58058.jpg
#   inflating: noisy-images/noisy-images/58059.jpg
#   inflating: noisy-images/noisy-images/5806.jpg
#   inflating: noisy-images/noisy-images/58060.jpg
#   inflating: noisy-images/noisy-images/58061.jpg
#   inflating: noisy-images/noisy-images/58062.jpg
#   inflating: noisy-images/noisy-images/58063.jpg
#   inflating: noisy-images/noisy-images/5807.jpg
#   inflating: noisy-images/noisy-images/58071.jpg
#   inflating: noisy-images/noisy-images/58072.jpg
#   inflating: noisy-images/noisy-images/58073.jpg
#   inflating: noisy-images/noisy-images/58074.jpg
#   inflating: noisy-images/noisy-images/58075.jpg
#   inflating: noisy-images/noisy-images/58076.jpg
#   inflating: noisy-images/noisy-images/58078.jpg
#   inflating: noisy-images/noisy-images/5808.jpg
#   inflating: noisy-images/noisy-images/58085.jpg
#   inflating: noisy-images/noisy-images/58086.jpg
#   inflating: noisy-images/noisy-images/58087.jpg
#   inflating: noisy-images/noisy-images/5809.jpg
#   inflating: noisy-images/noisy-images/58093.jpg
#   inflating: noisy-images/noisy-images/58096.jpg
#   inflating: noisy-images/noisy-images/58097.jpg
#   inflating: noisy-images/noisy-images/58098.jpg
#   inflating: noisy-images/noisy-images/58099.jpg
#   inflating: noisy-images/noisy-images/5810.jpg
#   inflating: noisy-images/noisy-images/58100.jpg
#   inflating: noisy-images/noisy-images/58104.jpg
#   inflating: noisy-images/noisy-images/58107.jpg
#   inflating: noisy-images/noisy-images/58108.jpg
#   inflating: noisy-images/noisy-images/58109.jpg
#   inflating: noisy-images/noisy-images/5811.jpg
#   inflating: noisy-images/noisy-images/58110.jpg
#   inflating: noisy-images/noisy-images/58111.jpg
#   inflating: noisy-images/noisy-images/58112.jpg
#   inflating: noisy-images/noisy-images/58115.jpg
#   inflating: noisy-images/noisy-images/58116.jpg
#   inflating: noisy-images/noisy-images/58117.jpg
#   inflating: noisy-images/noisy-images/58118.jpg
#   inflating: noisy-images/noisy-images/5812.jpg
#   inflating: noisy-images/noisy-images/58121.jpg
#   inflating: noisy-images/noisy-images/58123.jpg
#   inflating: noisy-images/noisy-images/58128.jpg
#   inflating: noisy-images/noisy-images/58129.jpg
#   inflating: noisy-images/noisy-images/5813.jpg
#   inflating: noisy-images/noisy-images/58131.jpg
#   inflating: noisy-images/noisy-images/58132.jpg
#   inflating: noisy-images/noisy-images/58133.jpg
#   inflating: noisy-images/noisy-images/58135.jpg
#   inflating: noisy-images/noisy-images/58136.jpg
#   inflating: noisy-images/noisy-images/58137.jpg
#   inflating: noisy-images/noisy-images/58138.jpg
#   inflating: noisy-images/noisy-images/58139.jpg
#   inflating: noisy-images/noisy-images/5814.jpg
#   inflating: noisy-images/noisy-images/58140.jpg
#   inflating: noisy-images/noisy-images/58141.jpg
#   inflating: noisy-images/noisy-images/58143.jpg
#   inflating: noisy-images/noisy-images/58146.jpg
#   inflating: noisy-images/noisy-images/58147.jpg
#   inflating: noisy-images/noisy-images/58148.jpg
#   inflating: noisy-images/noisy-images/58149.jpg
#   inflating: noisy-images/noisy-images/5815.jpg
#   inflating: noisy-images/noisy-images/58150.jpg
#   inflating: noisy-images/noisy-images/58151.jpg
#   inflating: noisy-images/noisy-images/58152.jpg
#   inflating: noisy-images/noisy-images/58153.jpg
#   inflating: noisy-images/noisy-images/58154.jpg
#   inflating: noisy-images/noisy-images/58155.jpg
#   inflating: noisy-images/noisy-images/58156.jpg
#   inflating: noisy-images/noisy-images/58157.jpg
#   inflating: noisy-images/noisy-images/58158.jpg
#   inflating: noisy-images/noisy-images/58159.jpg
#   inflating: noisy-images/noisy-images/5816.jpg
#   inflating: noisy-images/noisy-images/58160.jpg
#   inflating: noisy-images/noisy-images/58161.jpg
#   inflating: noisy-images/noisy-images/58162.jpg
#   inflating: noisy-images/noisy-images/58163.jpg
#   inflating: noisy-images/noisy-images/58164.jpg
#   inflating: noisy-images/noisy-images/58165.jpg
#   inflating: noisy-images/noisy-images/58166.jpg
#   inflating: noisy-images/noisy-images/58167.jpg
#   inflating: noisy-images/noisy-images/58168.jpg
#   inflating: noisy-images/noisy-images/58169.jpg
#   inflating: noisy-images/noisy-images/5817.jpg
#   inflating: noisy-images/noisy-images/58170.jpg
#   inflating: noisy-images/noisy-images/58171.jpg
#   inflating: noisy-images/noisy-images/58172.jpg
#   inflating: noisy-images/noisy-images/58173.jpg
#   inflating: noisy-images/noisy-images/58174.jpg
#   inflating: noisy-images/noisy-images/58175.jpg
#   inflating: noisy-images/noisy-images/58176.jpg
#   inflating: noisy-images/noisy-images/58177.jpg
#   inflating: noisy-images/noisy-images/58178.jpg
#   inflating: noisy-images/noisy-images/58179.jpg
#   inflating: noisy-images/noisy-images/5818.jpg
#   inflating: noisy-images/noisy-images/58180.jpg
#   inflating: noisy-images/noisy-images/58181.jpg
#   inflating: noisy-images/noisy-images/58182.jpg
#   inflating: noisy-images/noisy-images/58183.jpg
#   inflating: noisy-images/noisy-images/58184.jpg
#   inflating: noisy-images/noisy-images/58185.jpg
#   inflating: noisy-images/noisy-images/58186.jpg
#   inflating: noisy-images/noisy-images/58187.jpg
#   inflating: noisy-images/noisy-images/58188.jpg
#   inflating: noisy-images/noisy-images/58189.jpg
#   inflating: noisy-images/noisy-images/5819.jpg
#   inflating: noisy-images/noisy-images/58190.jpg
#   inflating: noisy-images/noisy-images/58191.jpg
#   inflating: noisy-images/noisy-images/58194.jpg
#   inflating: noisy-images/noisy-images/58195.jpg
#   inflating: noisy-images/noisy-images/58196.jpg
#   inflating: noisy-images/noisy-images/5820.jpg
#   inflating: noisy-images/noisy-images/58200.jpg
#   inflating: noisy-images/noisy-images/58201.jpg
#   inflating: noisy-images/noisy-images/58202.jpg
#   inflating: noisy-images/noisy-images/58204.jpg
#   inflating: noisy-images/noisy-images/58205.jpg
#   inflating: noisy-images/noisy-images/58206.jpg
#   inflating: noisy-images/noisy-images/58207.jpg
#   inflating: noisy-images/noisy-images/58208.jpg
#   inflating: noisy-images/noisy-images/58209.jpg
#   inflating: noisy-images/noisy-images/5821.jpg
#   inflating: noisy-images/noisy-images/58210.jpg
#   inflating: noisy-images/noisy-images/58211.jpg
#   inflating: noisy-images/noisy-images/58212.jpg
#   inflating: noisy-images/noisy-images/58213.jpg
#   inflating: noisy-images/noisy-images/58214.jpg
#   inflating: noisy-images/noisy-images/58215.jpg
#   inflating: noisy-images/noisy-images/58216.jpg
#   inflating: noisy-images/noisy-images/58218.jpg
#   inflating: noisy-images/noisy-images/5822.jpg
#   inflating: noisy-images/noisy-images/58220.jpg
#   inflating: noisy-images/noisy-images/58222.jpg
#   inflating: noisy-images/noisy-images/58225.jpg
#   inflating: noisy-images/noisy-images/58226.jpg
#   inflating: noisy-images/noisy-images/58227.jpg
#   inflating: noisy-images/noisy-images/58229.jpg
#   inflating: noisy-images/noisy-images/5823.jpg
#   inflating: noisy-images/noisy-images/58231.jpg
#   inflating: noisy-images/noisy-images/58232.jpg
#   inflating: noisy-images/noisy-images/58233.jpg
#   inflating: noisy-images/noisy-images/58234.jpg
#   inflating: noisy-images/noisy-images/58235.jpg
#   inflating: noisy-images/noisy-images/58236.jpg
#   inflating: noisy-images/noisy-images/58237.jpg
#   inflating: noisy-images/noisy-images/58238.jpg
#   inflating: noisy-images/noisy-images/58239.jpg
#   inflating: noisy-images/noisy-images/5824.jpg
#   inflating: noisy-images/noisy-images/58241.jpg
#   inflating: noisy-images/noisy-images/58242.jpg
#   inflating: noisy-images/noisy-images/58243.jpg
#   inflating: noisy-images/noisy-images/58244.jpg
#   inflating: noisy-images/noisy-images/58245.jpg
#   inflating: noisy-images/noisy-images/58246.jpg
#   inflating: noisy-images/noisy-images/58247.jpg
#   inflating: noisy-images/noisy-images/58248.jpg
#   inflating: noisy-images/noisy-images/58249.jpg
#   inflating: noisy-images/noisy-images/5825.jpg
#   inflating: noisy-images/noisy-images/58250.jpg
#   inflating: noisy-images/noisy-images/58251.jpg
#   inflating: noisy-images/noisy-images/58252.jpg
#   inflating: noisy-images/noisy-images/58253.jpg
#   inflating: noisy-images/noisy-images/58254.jpg
#   inflating: noisy-images/noisy-images/58255.jpg
#   inflating: noisy-images/noisy-images/58256.jpg
#   inflating: noisy-images/noisy-images/58257.jpg
#   inflating: noisy-images/noisy-images/58258.jpg
#   inflating: noisy-images/noisy-images/58259.jpg
#   inflating: noisy-images/noisy-images/5826.jpg
#   inflating: noisy-images/noisy-images/58260.jpg
#   inflating: noisy-images/noisy-images/58261.jpg
#   inflating: noisy-images/noisy-images/58262.jpg
#   inflating: noisy-images/noisy-images/58263.jpg
#   inflating: noisy-images/noisy-images/58264.jpg
#   inflating: noisy-images/noisy-images/58265.jpg
#   inflating: noisy-images/noisy-images/58266.jpg
#   inflating: noisy-images/noisy-images/58267.jpg
#   inflating: noisy-images/noisy-images/58268.jpg
#   inflating: noisy-images/noisy-images/58269.jpg
#   inflating: noisy-images/noisy-images/5827.jpg
#   inflating: noisy-images/noisy-images/58270.jpg
#   inflating: noisy-images/noisy-images/58271.jpg
#   inflating: noisy-images/noisy-images/58272.jpg
#   inflating: noisy-images/noisy-images/58273.jpg
#   inflating: noisy-images/noisy-images/58274.jpg
#   inflating: noisy-images/noisy-images/58275.jpg
#   inflating: noisy-images/noisy-images/58276.jpg
#   inflating: noisy-images/noisy-images/58277.jpg
#   inflating: noisy-images/noisy-images/58278.jpg
#   inflating: noisy-images/noisy-images/58279.jpg
#   inflating: noisy-images/noisy-images/5828.jpg
#   inflating: noisy-images/noisy-images/58280.jpg
#   inflating: noisy-images/noisy-images/58281.jpg
#   inflating: noisy-images/noisy-images/58282.jpg
#   inflating: noisy-images/noisy-images/58283.jpg
#   inflating: noisy-images/noisy-images/58284.jpg
#   inflating: noisy-images/noisy-images/58286.jpg
#   inflating: noisy-images/noisy-images/5829.jpg
#   inflating: noisy-images/noisy-images/58291.jpg
#   inflating: noisy-images/noisy-images/58292.jpg
#   inflating: noisy-images/noisy-images/58293.jpg
#   inflating: noisy-images/noisy-images/58294.jpg
#   inflating: noisy-images/noisy-images/58295.jpg
#   inflating: noisy-images/noisy-images/58296.jpg
#   inflating: noisy-images/noisy-images/58297.jpg
#   inflating: noisy-images/noisy-images/58298.jpg
#   inflating: noisy-images/noisy-images/58299.jpg
#   inflating: noisy-images/noisy-images/5830.jpg
#   inflating: noisy-images/noisy-images/58300.jpg
#   inflating: noisy-images/noisy-images/58304.jpg
#   inflating: noisy-images/noisy-images/58305.jpg
#   inflating: noisy-images/noisy-images/58306.jpg
#   inflating: noisy-images/noisy-images/58307.jpg
#   inflating: noisy-images/noisy-images/58308.jpg
#   inflating: noisy-images/noisy-images/58309.jpg
#   inflating: noisy-images/noisy-images/5831.jpg
#   inflating: noisy-images/noisy-images/58310.jpg
#   inflating: noisy-images/noisy-images/58311.jpg
#   inflating: noisy-images/noisy-images/58312.jpg
#   inflating: noisy-images/noisy-images/58313.jpg
#   inflating: noisy-images/noisy-images/58314.jpg
#   inflating: noisy-images/noisy-images/58315.jpg
#   inflating: noisy-images/noisy-images/58316.jpg
#   inflating: noisy-images/noisy-images/58317.jpg
#   inflating: noisy-images/noisy-images/58318.jpg
#   inflating: noisy-images/noisy-images/58319.jpg
#   inflating: noisy-images/noisy-images/5832.jpg
#   inflating: noisy-images/noisy-images/58320.jpg
#   inflating: noisy-images/noisy-images/58321.jpg
#   inflating: noisy-images/noisy-images/58322.jpg
#   inflating: noisy-images/noisy-images/58323.jpg
#   inflating: noisy-images/noisy-images/58324.jpg
#   inflating: noisy-images/noisy-images/58325.jpg
#   inflating: noisy-images/noisy-images/58326.jpg
#   inflating: noisy-images/noisy-images/58327.jpg
#   inflating: noisy-images/noisy-images/58328.jpg
#   inflating: noisy-images/noisy-images/58329.jpg
#   inflating: noisy-images/noisy-images/5833.jpg
#   inflating: noisy-images/noisy-images/58330.jpg
#   inflating: noisy-images/noisy-images/58331.jpg
#   inflating: noisy-images/noisy-images/58332.jpg
#   inflating: noisy-images/noisy-images/58333.jpg
#   inflating: noisy-images/noisy-images/58334.jpg
#   inflating: noisy-images/noisy-images/58335.jpg
#   inflating: noisy-images/noisy-images/58336.jpg
#   inflating: noisy-images/noisy-images/58337.jpg
#   inflating: noisy-images/noisy-images/58338.jpg
#   inflating: noisy-images/noisy-images/58339.jpg
#   inflating: noisy-images/noisy-images/5834.jpg
#   inflating: noisy-images/noisy-images/58340.jpg
#   inflating: noisy-images/noisy-images/58349.jpg
#   inflating: noisy-images/noisy-images/5835.jpg
#   inflating: noisy-images/noisy-images/58351.jpg
#   inflating: noisy-images/noisy-images/58357.jpg
#   inflating: noisy-images/noisy-images/58358.jpg
#   inflating: noisy-images/noisy-images/5836.jpg
#   inflating: noisy-images/noisy-images/5837.jpg
#   inflating: noisy-images/noisy-images/58372.jpg
#   inflating: noisy-images/noisy-images/58375.jpg
#   inflating: noisy-images/noisy-images/5838.jpg
#   inflating: noisy-images/noisy-images/58381.jpg
#   inflating: noisy-images/noisy-images/58385.jpg
#   inflating: noisy-images/noisy-images/5839.jpg
#   inflating: noisy-images/noisy-images/58394.jpg
#   inflating: noisy-images/noisy-images/58395.jpg
#   inflating: noisy-images/noisy-images/5840.jpg
#   inflating: noisy-images/noisy-images/5841.jpg
#   inflating: noisy-images/noisy-images/58411.jpg
#   inflating: noisy-images/noisy-images/58418.jpg
#   inflating: noisy-images/noisy-images/5842.jpg
#   inflating: noisy-images/noisy-images/58425.jpg
#   inflating: noisy-images/noisy-images/5843.jpg
#   inflating: noisy-images/noisy-images/58439.jpg
#   inflating: noisy-images/noisy-images/5844.jpg
#   inflating: noisy-images/noisy-images/58444.jpg
#   inflating: noisy-images/noisy-images/58445.jpg
#   inflating: noisy-images/noisy-images/58446.jpg
#   inflating: noisy-images/noisy-images/58447.jpg
#   inflating: noisy-images/noisy-images/58448.jpg
#   inflating: noisy-images/noisy-images/58449.jpg
#   inflating: noisy-images/noisy-images/5845.jpg
#   inflating: noisy-images/noisy-images/58451.jpg
#   inflating: noisy-images/noisy-images/58452.jpg
#   inflating: noisy-images/noisy-images/58453.jpg
#   inflating: noisy-images/noisy-images/58454.jpg
#   inflating: noisy-images/noisy-images/58455.jpg
#   inflating: noisy-images/noisy-images/58456.jpg
#   inflating: noisy-images/noisy-images/58458.jpg
#   inflating: noisy-images/noisy-images/58459.jpg
#   inflating: noisy-images/noisy-images/5846.jpg
#   inflating: noisy-images/noisy-images/58460.jpg
#   inflating: noisy-images/noisy-images/58463.jpg
#   inflating: noisy-images/noisy-images/58464.jpg
#   inflating: noisy-images/noisy-images/58465.jpg
#   inflating: noisy-images/noisy-images/58466.jpg
#   inflating: noisy-images/noisy-images/58467.jpg
#   inflating: noisy-images/noisy-images/58468.jpg
#   inflating: noisy-images/noisy-images/5847.jpg
#   inflating: noisy-images/noisy-images/58470.jpg
#   inflating: noisy-images/noisy-images/58471.jpg
#   inflating: noisy-images/noisy-images/58472.jpg
#   inflating: noisy-images/noisy-images/58473.jpg
#   inflating: noisy-images/noisy-images/58474.jpg
#   inflating: noisy-images/noisy-images/58475.jpg
#   inflating: noisy-images/noisy-images/58476.jpg
#   inflating: noisy-images/noisy-images/58477.jpg
#   inflating: noisy-images/noisy-images/58478.jpg
#   inflating: noisy-images/noisy-images/58479.jpg
#   inflating: noisy-images/noisy-images/5848.jpg
#   inflating: noisy-images/noisy-images/58480.jpg
#   inflating: noisy-images/noisy-images/58482.jpg
#   inflating: noisy-images/noisy-images/58483.jpg
#   inflating: noisy-images/noisy-images/58484.jpg
#   inflating: noisy-images/noisy-images/58485.jpg
#   inflating: noisy-images/noisy-images/58486.jpg
#   inflating: noisy-images/noisy-images/58487.jpg
#   inflating: noisy-images/noisy-images/58488.jpg
#   inflating: noisy-images/noisy-images/58489.jpg
#   inflating: noisy-images/noisy-images/5849.jpg
#   inflating: noisy-images/noisy-images/58490.jpg
#   inflating: noisy-images/noisy-images/58491.jpg
#   inflating: noisy-images/noisy-images/58492.jpg
#   inflating: noisy-images/noisy-images/58493.jpg
#   inflating: noisy-images/noisy-images/58494.jpg
#   inflating: noisy-images/noisy-images/58495.jpg
#   inflating: noisy-images/noisy-images/58496.jpg
#   inflating: noisy-images/noisy-images/58497.jpg
#   inflating: noisy-images/noisy-images/58498.jpg
#   inflating: noisy-images/noisy-images/58499.jpg
#   inflating: noisy-images/noisy-images/5850.jpg
#   inflating: noisy-images/noisy-images/58500.jpg
#   inflating: noisy-images/noisy-images/58501.jpg
#   inflating: noisy-images/noisy-images/58502.jpg
#   inflating: noisy-images/noisy-images/58503.jpg
#   inflating: noisy-images/noisy-images/58504.jpg
#   inflating: noisy-images/noisy-images/58505.jpg
#   inflating: noisy-images/noisy-images/58506.jpg
#   inflating: noisy-images/noisy-images/58507.jpg
#   inflating: noisy-images/noisy-images/58508.jpg
#   inflating: noisy-images/noisy-images/58509.jpg
#   inflating: noisy-images/noisy-images/5851.jpg
#   inflating: noisy-images/noisy-images/58510.jpg
#   inflating: noisy-images/noisy-images/58511.jpg
#   inflating: noisy-images/noisy-images/58512.jpg
#   inflating: noisy-images/noisy-images/58513.jpg
#   inflating: noisy-images/noisy-images/58514.jpg
#   inflating: noisy-images/noisy-images/58515.jpg
#   inflating: noisy-images/noisy-images/58516.jpg
#   inflating: noisy-images/noisy-images/58517.jpg
#   inflating: noisy-images/noisy-images/58518.jpg
#   inflating: noisy-images/noisy-images/58519.jpg
#   inflating: noisy-images/noisy-images/5852.jpg
#   inflating: noisy-images/noisy-images/58520.jpg
#   inflating: noisy-images/noisy-images/58521.jpg
#   inflating: noisy-images/noisy-images/58522.jpg
#   inflating: noisy-images/noisy-images/58523.jpg
#   inflating: noisy-images/noisy-images/58524.jpg
#   inflating: noisy-images/noisy-images/58525.jpg
#   inflating: noisy-images/noisy-images/58526.jpg
#   inflating: noisy-images/noisy-images/58527.jpg
#   inflating: noisy-images/noisy-images/58528.jpg
#   inflating: noisy-images/noisy-images/5853.jpg
#   inflating: noisy-images/noisy-images/58530.jpg
#   inflating: noisy-images/noisy-images/58531.jpg
#   inflating: noisy-images/noisy-images/58532.jpg
#   inflating: noisy-images/noisy-images/58533.jpg
#   inflating: noisy-images/noisy-images/58534.jpg
#   inflating: noisy-images/noisy-images/58535.jpg
#   inflating: noisy-images/noisy-images/58536.jpg
#   inflating: noisy-images/noisy-images/58537.jpg
#   inflating: noisy-images/noisy-images/58538.jpg
#   inflating: noisy-images/noisy-images/58539.jpg
#   inflating: noisy-images/noisy-images/5854.jpg
#   inflating: noisy-images/noisy-images/58540.jpg
#   inflating: noisy-images/noisy-images/58541.jpg
#   inflating: noisy-images/noisy-images/58542.jpg
#   inflating: noisy-images/noisy-images/58543.jpg
#   inflating: noisy-images/noisy-images/58544.jpg
#   inflating: noisy-images/noisy-images/58545.jpg
#   inflating: noisy-images/noisy-images/58546.jpg
#   inflating: noisy-images/noisy-images/58547.jpg
#   inflating: noisy-images/noisy-images/58548.jpg
#   inflating: noisy-images/noisy-images/58549.jpg
#   inflating: noisy-images/noisy-images/5855.jpg
#   inflating: noisy-images/noisy-images/58550.jpg
#   inflating: noisy-images/noisy-images/58551.jpg
#   inflating: noisy-images/noisy-images/58552.jpg
#   inflating: noisy-images/noisy-images/58553.jpg
#   inflating: noisy-images/noisy-images/58555.jpg
#   inflating: noisy-images/noisy-images/58559.jpg
#   inflating: noisy-images/noisy-images/5856.jpg
#   inflating: noisy-images/noisy-images/58560.jpg
#   inflating: noisy-images/noisy-images/58561.jpg
#   inflating: noisy-images/noisy-images/58562.jpg
#   inflating: noisy-images/noisy-images/58563.jpg
#   inflating: noisy-images/noisy-images/58565.jpg
#   inflating: noisy-images/noisy-images/58566.jpg
#   inflating: noisy-images/noisy-images/58567.jpg
#   inflating: noisy-images/noisy-images/58569.jpg
#   inflating: noisy-images/noisy-images/5857.jpg
#   inflating: noisy-images/noisy-images/58570.jpg
#   inflating: noisy-images/noisy-images/58571.jpg
#   inflating: noisy-images/noisy-images/58573.jpg
#   inflating: noisy-images/noisy-images/58574.jpg
#   inflating: noisy-images/noisy-images/58576.jpg
#   inflating: noisy-images/noisy-images/58577.jpg
#   inflating: noisy-images/noisy-images/5858.jpg
#   inflating: noisy-images/noisy-images/58581.jpg
#   inflating: noisy-images/noisy-images/58586.jpg
#   inflating: noisy-images/noisy-images/58588.jpg
#   inflating: noisy-images/noisy-images/58589.jpg
#   inflating: noisy-images/noisy-images/5859.jpg
#   inflating: noisy-images/noisy-images/58590.jpg
#   inflating: noisy-images/noisy-images/58591.jpg
#   inflating: noisy-images/noisy-images/5860.jpg
#   inflating: noisy-images/noisy-images/58600.jpg
#   inflating: noisy-images/noisy-images/58603.jpg
#   inflating: noisy-images/noisy-images/58606.jpg
#   inflating: noisy-images/noisy-images/58607.jpg
#   inflating: noisy-images/noisy-images/58608.jpg
#   inflating: noisy-images/noisy-images/58609.jpg
#   inflating: noisy-images/noisy-images/5861.jpg
#   inflating: noisy-images/noisy-images/58610.jpg
#   inflating: noisy-images/noisy-images/58611.jpg
#   inflating: noisy-images/noisy-images/58612.jpg
#   inflating: noisy-images/noisy-images/58614.jpg
#   inflating: noisy-images/noisy-images/58615.jpg
#   inflating: noisy-images/noisy-images/58618.jpg
#   inflating: noisy-images/noisy-images/5862.jpg
#   inflating: noisy-images/noisy-images/58620.jpg
#   inflating: noisy-images/noisy-images/58621.jpg
#   inflating: noisy-images/noisy-images/58622.jpg
#   inflating: noisy-images/noisy-images/58624.jpg
#   inflating: noisy-images/noisy-images/58625.jpg
#   inflating: noisy-images/noisy-images/58626.jpg
#   inflating: noisy-images/noisy-images/58627.jpg
#   inflating: noisy-images/noisy-images/58628.jpg
#   inflating: noisy-images/noisy-images/58629.jpg
#   inflating: noisy-images/noisy-images/5863.jpg
#   inflating: noisy-images/noisy-images/58634.jpg
#   inflating: noisy-images/noisy-images/58635.jpg
#   inflating: noisy-images/noisy-images/58636.jpg
#   inflating: noisy-images/noisy-images/58637.jpg
#   inflating: noisy-images/noisy-images/58638.jpg
#   inflating: noisy-images/noisy-images/58639.jpg
#   inflating: noisy-images/noisy-images/5864.jpg
#   inflating: noisy-images/noisy-images/58640.jpg
#   inflating: noisy-images/noisy-images/58641.jpg
#   inflating: noisy-images/noisy-images/58642.jpg
#   inflating: noisy-images/noisy-images/58643.jpg
#   inflating: noisy-images/noisy-images/58644.jpg
#   inflating: noisy-images/noisy-images/58645.jpg
#   inflating: noisy-images/noisy-images/58646.jpg
#   inflating: noisy-images/noisy-images/58647.jpg
#   inflating: noisy-images/noisy-images/58648.jpg
#   inflating: noisy-images/noisy-images/5865.jpg
#   inflating: noisy-images/noisy-images/58652.jpg
#   inflating: noisy-images/noisy-images/58653.jpg
#   inflating: noisy-images/noisy-images/58654.jpg
#   inflating: noisy-images/noisy-images/58655.jpg
#   inflating: noisy-images/noisy-images/58656.jpg
#   inflating: noisy-images/noisy-images/58657.jpg
#   inflating: noisy-images/noisy-images/58658.jpg
#   inflating: noisy-images/noisy-images/58659.jpg
#   inflating: noisy-images/noisy-images/5866.jpg
#   inflating: noisy-images/noisy-images/58660.jpg
#   inflating: noisy-images/noisy-images/58661.jpg
#   inflating: noisy-images/noisy-images/58662.jpg
#   inflating: noisy-images/noisy-images/58663.jpg
#   inflating: noisy-images/noisy-images/58664.jpg
#   inflating: noisy-images/noisy-images/58666.jpg
#   inflating: noisy-images/noisy-images/58667.jpg
#   inflating: noisy-images/noisy-images/58668.jpg
#   inflating: noisy-images/noisy-images/58669.jpg
#   inflating: noisy-images/noisy-images/5867.jpg
#   inflating: noisy-images/noisy-images/58670.jpg
#   inflating: noisy-images/noisy-images/58671.jpg
#   inflating: noisy-images/noisy-images/58672.jpg
#   inflating: noisy-images/noisy-images/58673.jpg
#   inflating: noisy-images/noisy-images/58674.jpg
#   inflating: noisy-images/noisy-images/58675.jpg
#   inflating: noisy-images/noisy-images/58676.jpg
#   inflating: noisy-images/noisy-images/58677.jpg
#   inflating: noisy-images/noisy-images/58678.jpg
#   inflating: noisy-images/noisy-images/5868.jpg
#   inflating: noisy-images/noisy-images/58680.jpg
#   inflating: noisy-images/noisy-images/58681.jpg
#   inflating: noisy-images/noisy-images/58682.jpg
#   inflating: noisy-images/noisy-images/58683.jpg
#   inflating: noisy-images/noisy-images/58684.jpg
#   inflating: noisy-images/noisy-images/58685.jpg
#   inflating: noisy-images/noisy-images/58686.jpg
#   inflating: noisy-images/noisy-images/58687.jpg
#   inflating: noisy-images/noisy-images/58689.jpg
#   inflating: noisy-images/noisy-images/5869.jpg
#   inflating: noisy-images/noisy-images/58690.jpg
#   inflating: noisy-images/noisy-images/58691.jpg
#   inflating: noisy-images/noisy-images/58692.jpg
#   inflating: noisy-images/noisy-images/58693.jpg
#   inflating: noisy-images/noisy-images/58694.jpg
#   inflating: noisy-images/noisy-images/58695.jpg
#   inflating: noisy-images/noisy-images/58696.jpg
#   inflating: noisy-images/noisy-images/58698.jpg
#   inflating: noisy-images/noisy-images/5870.jpg
#   inflating: noisy-images/noisy-images/58700.jpg
#   inflating: noisy-images/noisy-images/58701.jpg
#   inflating: noisy-images/noisy-images/58702.jpg
#   inflating: noisy-images/noisy-images/58703.jpg
#   inflating: noisy-images/noisy-images/5871.jpg
#   inflating: noisy-images/noisy-images/58718.jpg
#   inflating: noisy-images/noisy-images/58719.jpg
#   inflating: noisy-images/noisy-images/58720.jpg
#   inflating: noisy-images/noisy-images/58722.jpg
#   inflating: noisy-images/noisy-images/58723.jpg
#   inflating: noisy-images/noisy-images/58724.jpg
#   inflating: noisy-images/noisy-images/58725.jpg
#   inflating: noisy-images/noisy-images/58726.jpg
#   inflating: noisy-images/noisy-images/58727.jpg
#   inflating: noisy-images/noisy-images/58728.jpg
#   inflating: noisy-images/noisy-images/58729.jpg
#   inflating: noisy-images/noisy-images/5873.jpg
#   inflating: noisy-images/noisy-images/58730.jpg
#   inflating: noisy-images/noisy-images/58731.jpg
#   inflating: noisy-images/noisy-images/58732.jpg
#   inflating: noisy-images/noisy-images/58734.jpg
#   inflating: noisy-images/noisy-images/58735.jpg
#   inflating: noisy-images/noisy-images/58736.jpg
#   inflating: noisy-images/noisy-images/58737.jpg
#   inflating: noisy-images/noisy-images/58738.jpg
#   inflating: noisy-images/noisy-images/5874.jpg
#   inflating: noisy-images/noisy-images/58740.jpg
#   inflating: noisy-images/noisy-images/58741.jpg
#   inflating: noisy-images/noisy-images/58742.jpg
#   inflating: noisy-images/noisy-images/58743.jpg
#   inflating: noisy-images/noisy-images/58744.jpg
#   inflating: noisy-images/noisy-images/58745.jpg
#   inflating: noisy-images/noisy-images/5875.jpg
#   inflating: noisy-images/noisy-images/5876.jpg
#   inflating: noisy-images/noisy-images/58765.jpg
#   inflating: noisy-images/noisy-images/5877.jpg
#   inflating: noisy-images/noisy-images/58770.jpg
#   inflating: noisy-images/noisy-images/5878.jpg
#   inflating: noisy-images/noisy-images/5879.jpg
#   inflating: noisy-images/noisy-images/58793.jpg
#   inflating: noisy-images/noisy-images/58794.jpg
#   inflating: noisy-images/noisy-images/58795.jpg
#   inflating: noisy-images/noisy-images/58796.jpg
#   inflating: noisy-images/noisy-images/58797.jpg
#   inflating: noisy-images/noisy-images/58798.jpg
#   inflating: noisy-images/noisy-images/58800.jpg
#   inflating: noisy-images/noisy-images/58801.jpg
#   inflating: noisy-images/noisy-images/58802.jpg
#   inflating: noisy-images/noisy-images/58805.jpg
#   inflating: noisy-images/noisy-images/58807.jpg
#   inflating: noisy-images/noisy-images/58808.jpg
#   inflating: noisy-images/noisy-images/58809.jpg
#   inflating: noisy-images/noisy-images/5881.jpg
#   inflating: noisy-images/noisy-images/58810.jpg
#   inflating: noisy-images/noisy-images/58815.jpg
#   inflating: noisy-images/noisy-images/58816.jpg
#   inflating: noisy-images/noisy-images/58817.jpg
#   inflating: noisy-images/noisy-images/58818.jpg
#   inflating: noisy-images/noisy-images/58819.jpg
#   inflating: noisy-images/noisy-images/5882.jpg
#   inflating: noisy-images/noisy-images/58820.jpg
#   inflating: noisy-images/noisy-images/58821.jpg
#   inflating: noisy-images/noisy-images/58822.jpg
#   inflating: noisy-images/noisy-images/58825.jpg
#   inflating: noisy-images/noisy-images/58827.jpg
#   inflating: noisy-images/noisy-images/58828.jpg
#   inflating: noisy-images/noisy-images/58829.jpg
#   inflating: noisy-images/noisy-images/5883.jpg
#   inflating: noisy-images/noisy-images/58830.jpg
#   inflating: noisy-images/noisy-images/58831.jpg
#   inflating: noisy-images/noisy-images/58832.jpg
#   inflating: noisy-images/noisy-images/58833.jpg
#   inflating: noisy-images/noisy-images/58835.jpg
#   inflating: noisy-images/noisy-images/58836.jpg
#   inflating: noisy-images/noisy-images/58837.jpg
#   inflating: noisy-images/noisy-images/58838.jpg
#   inflating: noisy-images/noisy-images/58839.jpg
#   inflating: noisy-images/noisy-images/5884.jpg
#   inflating: noisy-images/noisy-images/58840.jpg
#   inflating: noisy-images/noisy-images/58841.jpg
#   inflating: noisy-images/noisy-images/58842.jpg
#   inflating: noisy-images/noisy-images/58843.jpg
#   inflating: noisy-images/noisy-images/58844.jpg
#   inflating: noisy-images/noisy-images/58845.jpg
#   inflating: noisy-images/noisy-images/58846.jpg
#   inflating: noisy-images/noisy-images/58847.jpg
#   inflating: noisy-images/noisy-images/58848.jpg
#   inflating: noisy-images/noisy-images/58849.jpg
#   inflating: noisy-images/noisy-images/5885.jpg
#   inflating: noisy-images/noisy-images/58850.jpg
#   inflating: noisy-images/noisy-images/58851.jpg
#   inflating: noisy-images/noisy-images/58852.jpg
#   inflating: noisy-images/noisy-images/58853.jpg
#   inflating: noisy-images/noisy-images/58854.jpg
#   inflating: noisy-images/noisy-images/58855.jpg
#   inflating: noisy-images/noisy-images/58857.jpg
#   inflating: noisy-images/noisy-images/58858.jpg
#   inflating: noisy-images/noisy-images/58859.jpg
#   inflating: noisy-images/noisy-images/5886.jpg
#   inflating: noisy-images/noisy-images/58860.jpg
#   inflating: noisy-images/noisy-images/58861.jpg
#   inflating: noisy-images/noisy-images/58862.jpg
#   inflating: noisy-images/noisy-images/58863.jpg
#   inflating: noisy-images/noisy-images/58864.jpg
#   inflating: noisy-images/noisy-images/58865.jpg
#   inflating: noisy-images/noisy-images/58867.jpg
#   inflating: noisy-images/noisy-images/58868.jpg
#   inflating: noisy-images/noisy-images/58869.jpg
#   inflating: noisy-images/noisy-images/5887.jpg
#   inflating: noisy-images/noisy-images/58870.jpg
#   inflating: noisy-images/noisy-images/58871.jpg
#   inflating: noisy-images/noisy-images/58872.jpg
#   inflating: noisy-images/noisy-images/58873.jpg
#   inflating: noisy-images/noisy-images/58874.jpg
#   inflating: noisy-images/noisy-images/58875.jpg
#   inflating: noisy-images/noisy-images/58876.jpg
#   inflating: noisy-images/noisy-images/58877.jpg
#   inflating: noisy-images/noisy-images/58878.jpg
#   inflating: noisy-images/noisy-images/58879.jpg
#   inflating: noisy-images/noisy-images/5888.jpg
#   inflating: noisy-images/noisy-images/58880.jpg
#   inflating: noisy-images/noisy-images/58881.jpg
#   inflating: noisy-images/noisy-images/58882.jpg
#   inflating: noisy-images/noisy-images/58883.jpg
#   inflating: noisy-images/noisy-images/58884.jpg
#   inflating: noisy-images/noisy-images/58885.jpg
#   inflating: noisy-images/noisy-images/58886.jpg
#   inflating: noisy-images/noisy-images/58887.jpg
#   inflating: noisy-images/noisy-images/58888.jpg
#   inflating: noisy-images/noisy-images/58889.jpg
#   inflating: noisy-images/noisy-images/5889.jpg
#   inflating: noisy-images/noisy-images/58890.jpg
#   inflating: noisy-images/noisy-images/58891.jpg
#   inflating: noisy-images/noisy-images/58892.jpg
#   inflating: noisy-images/noisy-images/58893.jpg
#   inflating: noisy-images/noisy-images/58896.jpg
#   inflating: noisy-images/noisy-images/58897.jpg
#   inflating: noisy-images/noisy-images/58898.jpg
#   inflating: noisy-images/noisy-images/58899.jpg
#   inflating: noisy-images/noisy-images/5890.jpg
#   inflating: noisy-images/noisy-images/58901.jpg
#   inflating: noisy-images/noisy-images/58902.jpg
#   inflating: noisy-images/noisy-images/58903.jpg
#   inflating: noisy-images/noisy-images/58904.jpg
#   inflating: noisy-images/noisy-images/58905.jpg
#   inflating: noisy-images/noisy-images/58906.jpg
#   inflating: noisy-images/noisy-images/58907.jpg
#   inflating: noisy-images/noisy-images/58908.jpg
#   inflating: noisy-images/noisy-images/58909.jpg
#   inflating: noisy-images/noisy-images/5891.jpg
#   inflating: noisy-images/noisy-images/58910.jpg
#   inflating: noisy-images/noisy-images/58911.jpg
#   inflating: noisy-images/noisy-images/58912.jpg
#   inflating: noisy-images/noisy-images/58913.jpg
#   inflating: noisy-images/noisy-images/58914.jpg
#   inflating: noisy-images/noisy-images/58915.jpg
#   inflating: noisy-images/noisy-images/58916.jpg
#   inflating: noisy-images/noisy-images/58917.jpg
#   inflating: noisy-images/noisy-images/58918.jpg
#   inflating: noisy-images/noisy-images/58919.jpg
#   inflating: noisy-images/noisy-images/5892.jpg
#   inflating: noisy-images/noisy-images/58920.jpg
#   inflating: noisy-images/noisy-images/58921.jpg
#   inflating: noisy-images/noisy-images/58922.jpg
#   inflating: noisy-images/noisy-images/58923.jpg
#   inflating: noisy-images/noisy-images/58924.jpg
#   inflating: noisy-images/noisy-images/58925.jpg
#   inflating: noisy-images/noisy-images/58926.jpg
#   inflating: noisy-images/noisy-images/58928.jpg
#   inflating: noisy-images/noisy-images/5893.jpg
#   inflating: noisy-images/noisy-images/58931.jpg
#   inflating: noisy-images/noisy-images/58932.jpg
#   inflating: noisy-images/noisy-images/58934.jpg
#   inflating: noisy-images/noisy-images/58935.jpg
#   inflating: noisy-images/noisy-images/58937.jpg
#   inflating: noisy-images/noisy-images/58939.jpg
#   inflating: noisy-images/noisy-images/5894.jpg
#   inflating: noisy-images/noisy-images/58940.jpg
#   inflating: noisy-images/noisy-images/58941.jpg
#   inflating: noisy-images/noisy-images/58942.jpg
#   inflating: noisy-images/noisy-images/58943.jpg
#   inflating: noisy-images/noisy-images/58944.jpg
#   inflating: noisy-images/noisy-images/58945.jpg
#   inflating: noisy-images/noisy-images/58946.jpg
#   inflating: noisy-images/noisy-images/58947.jpg
#   inflating: noisy-images/noisy-images/58948.jpg
#   inflating: noisy-images/noisy-images/58949.jpg
#   inflating: noisy-images/noisy-images/5895.jpg
#   inflating: noisy-images/noisy-images/58950.jpg
#   inflating: noisy-images/noisy-images/58951.jpg
#   inflating: noisy-images/noisy-images/58952.jpg
#   inflating: noisy-images/noisy-images/58954.jpg
#   inflating: noisy-images/noisy-images/58955.jpg
#   inflating: noisy-images/noisy-images/58956.jpg
#   inflating: noisy-images/noisy-images/58958.jpg
#   inflating: noisy-images/noisy-images/58959.jpg
#   inflating: noisy-images/noisy-images/5896.jpg
#   inflating: noisy-images/noisy-images/58960.jpg
#   inflating: noisy-images/noisy-images/58961.jpg
#   inflating: noisy-images/noisy-images/58962.jpg
#   inflating: noisy-images/noisy-images/58963.jpg
#   inflating: noisy-images/noisy-images/58964.jpg
#   inflating: noisy-images/noisy-images/58965.jpg
#   inflating: noisy-images/noisy-images/58966.jpg
#   inflating: noisy-images/noisy-images/58967.jpg
#   inflating: noisy-images/noisy-images/58968.jpg
#   inflating: noisy-images/noisy-images/58969.jpg
#   inflating: noisy-images/noisy-images/5897.jpg
#   inflating: noisy-images/noisy-images/58970.jpg
#   inflating: noisy-images/noisy-images/58971.jpg
#   inflating: noisy-images/noisy-images/58972.jpg
#   inflating: noisy-images/noisy-images/58973.jpg
#   inflating: noisy-images/noisy-images/58974.jpg
#   inflating: noisy-images/noisy-images/58975.jpg
#   inflating: noisy-images/noisy-images/58976.jpg
#   inflating: noisy-images/noisy-images/58977.jpg
#   inflating: noisy-images/noisy-images/58978.jpg
#   inflating: noisy-images/noisy-images/58979.jpg
#   inflating: noisy-images/noisy-images/5898.jpg
#   inflating: noisy-images/noisy-images/58980.jpg
#   inflating: noisy-images/noisy-images/58981.jpg
#   inflating: noisy-images/noisy-images/58982.jpg
#   inflating: noisy-images/noisy-images/58983.jpg
#   inflating: noisy-images/noisy-images/58984.jpg
#   inflating: noisy-images/noisy-images/58985.jpg
#   inflating: noisy-images/noisy-images/58986.jpg
#   inflating: noisy-images/noisy-images/58987.jpg
#   inflating: noisy-images/noisy-images/58988.jpg
#   inflating: noisy-images/noisy-images/58989.jpg
#   inflating: noisy-images/noisy-images/5899.jpg
#   inflating: noisy-images/noisy-images/58990.jpg
#   inflating: noisy-images/noisy-images/58991.jpg
#   inflating: noisy-images/noisy-images/58992.jpg
#   inflating: noisy-images/noisy-images/5900.jpg
#   inflating: noisy-images/noisy-images/59002.jpg
#   inflating: noisy-images/noisy-images/59003.jpg
#   inflating: noisy-images/noisy-images/59004.jpg
#   inflating: noisy-images/noisy-images/59005.jpg
#   inflating: noisy-images/noisy-images/59006.jpg
#   inflating: noisy-images/noisy-images/59008.jpg
#   inflating: noisy-images/noisy-images/5901.jpg
#   inflating: noisy-images/noisy-images/59010.jpg
#   inflating: noisy-images/noisy-images/59011.jpg
#   inflating: noisy-images/noisy-images/59012.jpg
#   inflating: noisy-images/noisy-images/59013.jpg
#   inflating: noisy-images/noisy-images/59014.jpg
#   inflating: noisy-images/noisy-images/59015.jpg
#   inflating: noisy-images/noisy-images/59016.jpg
#   inflating: noisy-images/noisy-images/59017.jpg
#   inflating: noisy-images/noisy-images/59018.jpg
#   inflating: noisy-images/noisy-images/59019.jpg
#   inflating: noisy-images/noisy-images/5902.jpg
#   inflating: noisy-images/noisy-images/59020.jpg
#   inflating: noisy-images/noisy-images/59021.jpg
#   inflating: noisy-images/noisy-images/59022.jpg
#   inflating: noisy-images/noisy-images/59023.jpg
#   inflating: noisy-images/noisy-images/59024.jpg
#   inflating: noisy-images/noisy-images/59025.jpg
#   inflating: noisy-images/noisy-images/59026.jpg
#   inflating: noisy-images/noisy-images/59027.jpg
#   inflating: noisy-images/noisy-images/59028.jpg
#   inflating: noisy-images/noisy-images/59029.jpg
#   inflating: noisy-images/noisy-images/5903.jpg
#   inflating: noisy-images/noisy-images/59030.jpg
#   inflating: noisy-images/noisy-images/59031.jpg
#   inflating: noisy-images/noisy-images/59032.jpg
#   inflating: noisy-images/noisy-images/59033.jpg
#   inflating: noisy-images/noisy-images/59034.jpg
#   inflating: noisy-images/noisy-images/59035.jpg
#   inflating: noisy-images/noisy-images/59036.jpg
#   inflating: noisy-images/noisy-images/59037.jpg
#   inflating: noisy-images/noisy-images/59038.jpg
#   inflating: noisy-images/noisy-images/59039.jpg
#   inflating: noisy-images/noisy-images/5904.jpg
#   inflating: noisy-images/noisy-images/59040.jpg
#   inflating: noisy-images/noisy-images/59042.jpg
#   inflating: noisy-images/noisy-images/59043.jpg
#   inflating: noisy-images/noisy-images/59044.jpg
#   inflating: noisy-images/noisy-images/59045.jpg
#   inflating: noisy-images/noisy-images/59046.jpg
#   inflating: noisy-images/noisy-images/59047.jpg
#   inflating: noisy-images/noisy-images/59048.jpg
#   inflating: noisy-images/noisy-images/59049.jpg
#   inflating: noisy-images/noisy-images/5905.jpg
#   inflating: noisy-images/noisy-images/59050.jpg
#   inflating: noisy-images/noisy-images/59051.jpg
#   inflating: noisy-images/noisy-images/59052.jpg
#   inflating: noisy-images/noisy-images/59053.jpg
#   inflating: noisy-images/noisy-images/59055.jpg
#   inflating: noisy-images/noisy-images/59056.jpg
#   inflating: noisy-images/noisy-images/59058.jpg
#   inflating: noisy-images/noisy-images/59059.jpg
#   inflating: noisy-images/noisy-images/5906.jpg
#   inflating: noisy-images/noisy-images/59060.jpg
#   inflating: noisy-images/noisy-images/59061.jpg
#   inflating: noisy-images/noisy-images/59062.jpg
#   inflating: noisy-images/noisy-images/59063.jpg
#   inflating: noisy-images/noisy-images/59064.jpg
#   inflating: noisy-images/noisy-images/59065.jpg
#   inflating: noisy-images/noisy-images/59066.jpg
#   inflating: noisy-images/noisy-images/59067.jpg
#   inflating: noisy-images/noisy-images/59068.jpg
#   inflating: noisy-images/noisy-images/59069.jpg
#   inflating: noisy-images/noisy-images/5907.jpg
#   inflating: noisy-images/noisy-images/59070.jpg
#   inflating: noisy-images/noisy-images/59071.jpg
#   inflating: noisy-images/noisy-images/59072.jpg
#   inflating: noisy-images/noisy-images/59073.jpg
#   inflating: noisy-images/noisy-images/59074.jpg
#   inflating: noisy-images/noisy-images/59075.jpg
#   inflating: noisy-images/noisy-images/59076.jpg
#   inflating: noisy-images/noisy-images/59077.jpg
#   inflating: noisy-images/noisy-images/59078.jpg
#   inflating: noisy-images/noisy-images/59079.jpg
#   inflating: noisy-images/noisy-images/5908.jpg
#   inflating: noisy-images/noisy-images/59080.jpg
#   inflating: noisy-images/noisy-images/59081.jpg
#   inflating: noisy-images/noisy-images/59082.jpg
#   inflating: noisy-images/noisy-images/59083.jpg
#   inflating: noisy-images/noisy-images/59084.jpg
#   inflating: noisy-images/noisy-images/59085.jpg
#   inflating: noisy-images/noisy-images/59086.jpg
#   inflating: noisy-images/noisy-images/59087.jpg
#   inflating: noisy-images/noisy-images/59088.jpg
#   inflating: noisy-images/noisy-images/59089.jpg
#   inflating: noisy-images/noisy-images/5909.jpg
#   inflating: noisy-images/noisy-images/59090.jpg
#   inflating: noisy-images/noisy-images/59091.jpg
#   inflating: noisy-images/noisy-images/59092.jpg
#   inflating: noisy-images/noisy-images/59093.jpg
#   inflating: noisy-images/noisy-images/59094.jpg
#   inflating: noisy-images/noisy-images/59095.jpg
#   inflating: noisy-images/noisy-images/59096.jpg
#   inflating: noisy-images/noisy-images/59097.jpg
#   inflating: noisy-images/noisy-images/59098.jpg
#   inflating: noisy-images/noisy-images/59099.jpg
#   inflating: noisy-images/noisy-images/5910.jpg
#   inflating: noisy-images/noisy-images/59100.jpg
#   inflating: noisy-images/noisy-images/59101.jpg
#   inflating: noisy-images/noisy-images/59102.jpg
#   inflating: noisy-images/noisy-images/59103.jpg
#   inflating: noisy-images/noisy-images/59104.jpg
#   inflating: noisy-images/noisy-images/59105.jpg
#   inflating: noisy-images/noisy-images/59106.jpg
#   inflating: noisy-images/noisy-images/5911.jpg
#   inflating: noisy-images/noisy-images/59112.jpg
#   inflating: noisy-images/noisy-images/59115.jpg
#   inflating: noisy-images/noisy-images/59116.jpg
#   inflating: noisy-images/noisy-images/59117.jpg
#   inflating: noisy-images/noisy-images/59118.jpg
#   inflating: noisy-images/noisy-images/59119.jpg
#   inflating: noisy-images/noisy-images/5912.jpg
#   inflating: noisy-images/noisy-images/59120.jpg
#   inflating: noisy-images/noisy-images/59121.jpg
#   inflating: noisy-images/noisy-images/59122.jpg
#   inflating: noisy-images/noisy-images/59123.jpg
#   inflating: noisy-images/noisy-images/59124.jpg
#   inflating: noisy-images/noisy-images/59126.jpg
#   inflating: noisy-images/noisy-images/59127.jpg
#   inflating: noisy-images/noisy-images/59128.jpg
#   inflating: noisy-images/noisy-images/59129.jpg
#   inflating: noisy-images/noisy-images/59130.jpg
#   inflating: noisy-images/noisy-images/59131.jpg
#   inflating: noisy-images/noisy-images/59132.jpg
#   inflating: noisy-images/noisy-images/59133.jpg
#   inflating: noisy-images/noisy-images/59142.jpg
#   inflating: noisy-images/noisy-images/59143.jpg
#   inflating: noisy-images/noisy-images/59144.jpg
#   inflating: noisy-images/noisy-images/59145.jpg
#   inflating: noisy-images/noisy-images/59146.jpg
#   inflating: noisy-images/noisy-images/59147.jpg
#   inflating: noisy-images/noisy-images/59149.jpg
#   inflating: noisy-images/noisy-images/5915.jpg
#   inflating: noisy-images/noisy-images/5916.jpg
#   inflating: noisy-images/noisy-images/59160.jpg
#   inflating: noisy-images/noisy-images/59161.jpg
#   inflating: noisy-images/noisy-images/59165.jpg
#   inflating: noisy-images/noisy-images/59166.jpg
#   inflating: noisy-images/noisy-images/59167.jpg
#   inflating: noisy-images/noisy-images/5917.jpg
#   inflating: noisy-images/noisy-images/59172.jpg
#   inflating: noisy-images/noisy-images/59173.jpg
#   inflating: noisy-images/noisy-images/59174.jpg
#   inflating: noisy-images/noisy-images/59175.jpg
#   inflating: noisy-images/noisy-images/59176.jpg
#   inflating: noisy-images/noisy-images/59177.jpg
#   inflating: noisy-images/noisy-images/59178.jpg
#   inflating: noisy-images/noisy-images/59181.jpg
#   inflating: noisy-images/noisy-images/59185.jpg
#   inflating: noisy-images/noisy-images/59187.jpg
#   inflating: noisy-images/noisy-images/59188.jpg
#   inflating: noisy-images/noisy-images/5919.jpg
#   inflating: noisy-images/noisy-images/59190.jpg
#   inflating: noisy-images/noisy-images/5920.jpg
#   inflating: noisy-images/noisy-images/5921.jpg
#   inflating: noisy-images/noisy-images/59212.jpg
#   inflating: noisy-images/noisy-images/59213.jpg
#   inflating: noisy-images/noisy-images/59214.jpg
#   inflating: noisy-images/noisy-images/59215.jpg
#   inflating: noisy-images/noisy-images/59216.jpg
#   inflating: noisy-images/noisy-images/59217.jpg
#   inflating: noisy-images/noisy-images/59218.jpg
#   inflating: noisy-images/noisy-images/5922.jpg
#   inflating: noisy-images/noisy-images/59220.jpg
#   inflating: noisy-images/noisy-images/59221.jpg
# ...
#   inflating: noisy-images/noisy-images/9616.jpg
#   inflating: noisy-images/noisy-images/9617.jpg
#   inflating: noisy-images/noisy-images/9618.jpg
#   inflating: noisy-images/noisy-images/9619.jpg
#   inflating: noisy-images/noisy-images/9620.jpg
#   inflating: noisy-images/noisy-images/9621.jpg
#   inflating: noisy-images/noisy-images/9622.jpg
#   inflating: noisy-images/noisy-images/9623.jpg
#   inflating: noisy-images/noisy-images/9624.jpg
#   inflating: noisy-images/noisy-images/9627.jpg
#   inflating: noisy-images/noisy-images/9628.jpg
#   inflating: noisy-images/noisy-images/9630.jpg
#   inflating: noisy-images/noisy-images/9631.jpg
#   inflating: noisy-images/noisy-images/9632.jpg
#   inflating: noisy-images/noisy-images/9633.jpg
#   inflating: noisy-images/noisy-images/9634.jpg
#   inflating: noisy-images/noisy-images/9635.jpg
#   inflating: noisy-images/noisy-images/9636.jpg
#   inflating: noisy-images/noisy-images/9637.jpg
#   inflating: noisy-images/noisy-images/9638.jpg
#   inflating: noisy-images/noisy-images/9639.jpg
#   inflating: noisy-images/noisy-images/9640.jpg
#   inflating: noisy-images/noisy-images/9641.jpg
#   inflating: noisy-images/noisy-images/9642.jpg
#   inflating: noisy-images/noisy-images/9643.jpg
#   inflating: noisy-images/noisy-images/9644.jpg
#   inflating: noisy-images/noisy-images/9645.jpg
#   inflating: noisy-images/noisy-images/9646.jpg
#   inflating: noisy-images/noisy-images/9647.jpg
#   inflating: noisy-images/noisy-images/9648.jpg
#   inflating: noisy-images/noisy-images/9649.jpg
#   inflating: noisy-images/noisy-images/9650.jpg
#   inflating: noisy-images/noisy-images/9651.jpg
#   inflating: noisy-images/noisy-images/9652.jpg
#   inflating: noisy-images/noisy-images/9653.jpg
#   inflating: noisy-images/noisy-images/9654.jpg
#   inflating: noisy-images/noisy-images/9655.jpg
#   inflating: noisy-images/noisy-images/9656.jpg
#   inflating: noisy-images/noisy-images/9657.jpg
#   inflating: noisy-images/noisy-images/9658.jpg
#   inflating: noisy-images/noisy-images/9659.jpg
#   inflating: noisy-images/noisy-images/9660.jpg
#   inflating: noisy-images/noisy-images/9661.jpg
#   inflating: noisy-images/noisy-images/9662.jpg
#   inflating: noisy-images/noisy-images/9664.jpg
#   inflating: noisy-images/noisy-images/9665.jpg
#   inflating: noisy-images/noisy-images/9666.jpg
#   inflating: noisy-images/noisy-images/9667.jpg
#   inflating: noisy-images/noisy-images/9669.jpg
#   inflating: noisy-images/noisy-images/9670.jpg
#   inflating: noisy-images/noisy-images/9671.jpg
#   inflating: noisy-images/noisy-images/9672.jpg
#   inflating: noisy-images/noisy-images/9673.jpg
#   inflating: noisy-images/noisy-images/9674.jpg
#   inflating: noisy-images/noisy-images/9675.jpg
#   inflating: noisy-images/noisy-images/9676.jpg
#   inflating: noisy-images/noisy-images/9677.jpg
#   inflating: noisy-images/noisy-images/9678.jpg
#   inflating: noisy-images/noisy-images/9679.jpg
#   inflating: noisy-images/noisy-images/9680.jpg
#   inflating: noisy-images/noisy-images/9681.jpg
#   inflating: noisy-images/noisy-images/9682.jpg
#   inflating: noisy-images/noisy-images/9683.jpg
#   inflating: noisy-images/noisy-images/9684.jpg
#   inflating: noisy-images/noisy-images/9685.jpg
#   inflating: noisy-images/noisy-images/9686.jpg
#   inflating: noisy-images/noisy-images/9687.jpg
#   inflating: noisy-images/noisy-images/9688.jpg
#   inflating: noisy-images/noisy-images/9689.jpg
#   inflating: noisy-images/noisy-images/9690.jpg
#   inflating: noisy-images/noisy-images/9691.jpg
#   inflating: noisy-images/noisy-images/9692.jpg
#   inflating: noisy-images/noisy-images/9694.jpg
#   inflating: noisy-images/noisy-images/9695.jpg
#   inflating: noisy-images/noisy-images/9696.jpg
#   inflating: noisy-images/noisy-images/9697.jpg
#   inflating: noisy-images/noisy-images/9698.jpg
#   inflating: noisy-images/noisy-images/9699.jpg
#   inflating: noisy-images/noisy-images/9700.jpg
#   inflating: noisy-images/noisy-images/9701.jpg
#   inflating: noisy-images/noisy-images/9702.jpg
#   inflating: noisy-images/noisy-images/9703.jpg
#   inflating: noisy-images/noisy-images/9704.jpg
#   inflating: noisy-images/noisy-images/9705.jpg
#   inflating: noisy-images/noisy-images/9706.jpg
#   inflating: noisy-images/noisy-images/9707.jpg
#   inflating: noisy-images/noisy-images/9708.jpg
#   inflating: noisy-images/noisy-images/9709.jpg
#   inflating: noisy-images/noisy-images/9710.jpg
#   inflating: noisy-images/noisy-images/9711.jpg
#   inflating: noisy-images/noisy-images/9712.jpg
#   inflating: noisy-images/noisy-images/9713.jpg
#   inflating: noisy-images/noisy-images/9714.jpg
#   inflating: noisy-images/noisy-images/9715.jpg
#   inflating: noisy-images/noisy-images/9716.jpg
#   inflating: noisy-images/noisy-images/9717.jpg
#   inflating: noisy-images/noisy-images/9718.jpg
#   inflating: noisy-images/noisy-images/9719.jpg
#   inflating: noisy-images/noisy-images/9720.jpg
#   inflating: noisy-images/noisy-images/9722.jpg
#   inflating: noisy-images/noisy-images/9726.jpg
#   inflating: noisy-images/noisy-images/9729.jpg
#   inflating: noisy-images/noisy-images/9730.jpg
#   inflating: noisy-images/noisy-images/9732.jpg
#   inflating: noisy-images/noisy-images/9733.jpg
#   inflating: noisy-images/noisy-images/9738.jpg
#   inflating: noisy-images/noisy-images/9748.jpg
#   inflating: noisy-images/noisy-images/9752.jpg
#   inflating: noisy-images/noisy-images/9754.jpg
#   inflating: noisy-images/noisy-images/9755.jpg
#   inflating: noisy-images/noisy-images/9756.jpg
#   inflating: noisy-images/noisy-images/9757.jpg
#   inflating: noisy-images/noisy-images/9758.jpg
#   inflating: noisy-images/noisy-images/9759.jpg
#   inflating: noisy-images/noisy-images/9760.jpg
#   inflating: noisy-images/noisy-images/9761.jpg
#   inflating: noisy-images/noisy-images/9762.jpg
#   inflating: noisy-images/noisy-images/9763.jpg
#   inflating: noisy-images/noisy-images/9764.jpg
#   inflating: noisy-images/noisy-images/9765.jpg
#   inflating: noisy-images/noisy-images/9766.jpg
#   inflating: noisy-images/noisy-images/9767.jpg
#   inflating: noisy-images/noisy-images/9768.jpg
#   inflating: noisy-images/noisy-images/9769.jpg
#   inflating: noisy-images/noisy-images/9770.jpg
#   inflating: noisy-images/noisy-images/9771.jpg
#   inflating: noisy-images/noisy-images/9772.jpg
#   inflating: noisy-images/noisy-images/9773.jpg
#   inflating: noisy-images/noisy-images/9774.jpg
#   inflating: noisy-images/noisy-images/9775.jpg
#   inflating: noisy-images/noisy-images/9776.jpg
#   inflating: noisy-images/noisy-images/9777.jpg
#   inflating: noisy-images/noisy-images/9778.jpg
#   inflating: noisy-images/noisy-images/9779.jpg
#   inflating: noisy-images/noisy-images/9780.jpg
#   inflating: noisy-images/noisy-images/9781.jpg
#   inflating: noisy-images/noisy-images/9782.jpg
#   inflating: noisy-images/noisy-images/9783.jpg
#   inflating: noisy-images/noisy-images/9784.jpg
#   inflating: noisy-images/noisy-images/9785.jpg
#   inflating: noisy-images/noisy-images/9788.jpg
#   inflating: noisy-images/noisy-images/9789.jpg
#   inflating: noisy-images/noisy-images/9790.jpg
#   inflating: noisy-images/noisy-images/9791.jpg
#   inflating: noisy-images/noisy-images/9792.jpg
#   inflating: noisy-images/noisy-images/9793.jpg
#   inflating: noisy-images/noisy-images/9794.jpg
#   inflating: noisy-images/noisy-images/9795.jpg
#   inflating: noisy-images/noisy-images/9796.jpg
#   inflating: noisy-images/noisy-images/9797.jpg
#   inflating: noisy-images/noisy-images/9798.jpg
#   inflating: noisy-images/noisy-images/9799.jpg
#   inflating: noisy-images/noisy-images/9800.jpg
#   inflating: noisy-images/noisy-images/9801.jpg
#   inflating: noisy-images/noisy-images/9802.jpg
#   inflating: noisy-images/noisy-images/9803.jpg
#   inflating: noisy-images/noisy-images/9804.jpg
#   inflating: noisy-images/noisy-images/9805.jpg
#   inflating: noisy-images/noisy-images/9806.jpg
#   inflating: noisy-images/noisy-images/9807.jpg
#   inflating: noisy-images/noisy-images/9808.jpg
#   inflating: noisy-images/noisy-images/9809.jpg
#   inflating: noisy-images/noisy-images/9810.jpg
#   inflating: noisy-images/noisy-images/9812.jpg
#   inflating: noisy-images/noisy-images/9814.jpg
#   inflating: noisy-images/noisy-images/9815.jpg
#   inflating: noisy-images/noisy-images/9816.jpg
#   inflating: noisy-images/noisy-images/9817.jpg
#   inflating: noisy-images/noisy-images/9818.jpg
#   inflating: noisy-images/noisy-images/9819.jpg
#   inflating: noisy-images/noisy-images/9820.jpg
#   inflating: noisy-images/noisy-images/9821.jpg
#   inflating: noisy-images/noisy-images/9822.jpg
#   inflating: noisy-images/noisy-images/9823.jpg
#   inflating: noisy-images/noisy-images/9824.jpg
#   inflating: noisy-images/noisy-images/9825.jpg
#   inflating: noisy-images/noisy-images/9826.jpg
#   inflating: noisy-images/noisy-images/9827.jpg
#   inflating: noisy-images/noisy-images/9828.jpg
#   inflating: noisy-images/noisy-images/9829.jpg
#   inflating: noisy-images/noisy-images/9830.jpg
#   inflating: noisy-images/noisy-images/9831.jpg
#   inflating: noisy-images/noisy-images/9832.jpg
#   inflating: noisy-images/noisy-images/9833.jpg
#   inflating: noisy-images/noisy-images/9834.jpg
#   inflating: noisy-images/noisy-images/9835.jpg
#   inflating: noisy-images/noisy-images/9836.jpg
#   inflating: noisy-images/noisy-images/9839.jpg
#   inflating: noisy-images/noisy-images/9840.jpg
#   inflating: noisy-images/noisy-images/9841.jpg
#   inflating: noisy-images/noisy-images/9842.jpg
#   inflating: noisy-images/noisy-images/9852.jpg
#   inflating: noisy-images/noisy-images/9854.jpg
#   inflating: noisy-images/noisy-images/9856.jpg
#   inflating: noisy-images/noisy-images/9857.jpg
#   inflating: noisy-images/noisy-images/9858.jpg
#   inflating: noisy-images/noisy-images/9859.jpg
#   inflating: noisy-images/noisy-images/9860.jpg
#   inflating: noisy-images/noisy-images/9862.jpg
#   inflating: noisy-images/noisy-images/9863.jpg
#   inflating: noisy-images/noisy-images/9864.jpg
#   inflating: noisy-images/noisy-images/9865.jpg
#   inflating: noisy-images/noisy-images/9866.jpg
#   inflating: noisy-images/noisy-images/9867.jpg
#   inflating: noisy-images/noisy-images/9868.jpg
#   inflating: noisy-images/noisy-images/9869.jpg
#   inflating: noisy-images/noisy-images/9870.jpg
#   inflating: noisy-images/noisy-images/9871.jpg
#   inflating: noisy-images/noisy-images/9874.jpg
#   inflating: noisy-images/noisy-images/9875.jpg
#   inflating: noisy-images/noisy-images/9876.jpg
#   inflating: noisy-images/noisy-images/9877.jpg
#   inflating: noisy-images/noisy-images/9878.jpg
#   inflating: noisy-images/noisy-images/9879.jpg
#   inflating: noisy-images/noisy-images/9880.jpg
#   inflating: noisy-images/noisy-images/9881.jpg
#   inflating: noisy-images/noisy-images/9882.jpg
#   inflating: noisy-images/noisy-images/9883.jpg
#   inflating: noisy-images/noisy-images/9884.jpg
#   inflating: noisy-images/noisy-images/9885.jpg
#   inflating: noisy-images/noisy-images/9892.jpg
#   inflating: noisy-images/noisy-images/9894.jpg
#   inflating: noisy-images/noisy-images/9900.jpg
#   inflating: noisy-images/noisy-images/9901.jpg
#   inflating: noisy-images/noisy-images/9902.jpg
#   inflating: noisy-images/noisy-images/9903.jpg
#   inflating: noisy-images/noisy-images/9904.jpg
#   inflating: noisy-images/noisy-images/9906.jpg
#   inflating: noisy-images/noisy-images/9907.jpg
#   inflating: noisy-images/noisy-images/9908.jpg
#   inflating: noisy-images/noisy-images/9909.jpg
#   inflating: noisy-images/noisy-images/9910.jpg
#   inflating: noisy-images/noisy-images/9911.jpg
#   inflating: noisy-images/noisy-images/9912.jpg
#   inflating: noisy-images/noisy-images/9913.jpg
#   inflating: noisy-images/noisy-images/9914.jpg
#   inflating: noisy-images/noisy-images/9915.jpg
#   inflating: noisy-images/noisy-images/9916.jpg
#   inflating: noisy-images/noisy-images/9917.jpg
#   inflating: noisy-images/noisy-images/9918.jpg
#   inflating: noisy-images/noisy-images/9919.jpg
#   inflating: noisy-images/noisy-images/9920.jpg
#   inflating: noisy-images/noisy-images/9921.jpg
#   inflating: noisy-images/noisy-images/9922.jpg
#   inflating: noisy-images/noisy-images/9923.jpg
#   inflating: noisy-images/noisy-images/9924.jpg
#   inflating: noisy-images/noisy-images/9925.jpg
#   inflating: noisy-images/noisy-images/9926.jpg
#   inflating: noisy-images/noisy-images/9927.jpg
#   inflating: noisy-images/noisy-images/9929.jpg
#   inflating: noisy-images/noisy-images/9931.jpg
#   inflating: noisy-images/noisy-images/9932.jpg
#   inflating: noisy-images/noisy-images/9933.jpg
#   inflating: noisy-images/noisy-images/9934.jpg
#   inflating: noisy-images/noisy-images/9935.jpg
#   inflating: noisy-images/noisy-images/9937.jpg
#   inflating: noisy-images/noisy-images/9938.jpg
#   inflating: noisy-images/noisy-images/9940.jpg
#   inflating: noisy-images/noisy-images/9941.jpg
#   inflating: noisy-images/noisy-images/9942.jpg
#   inflating: noisy-images/noisy-images/9943.jpg
#   inflating: noisy-images/noisy-images/9944.jpg
#   inflating: noisy-images/noisy-images/9945.jpg
#   inflating: noisy-images/noisy-images/9946.jpg
#   inflating: noisy-images/noisy-images/9947.jpg
#   inflating: noisy-images/noisy-images/9948.jpg
#   inflating: noisy-images/noisy-images/9949.jpg
#   inflating: noisy-images/noisy-images/9950.jpg
#   inflating: noisy-images/noisy-images/9951.jpg
#   inflating: noisy-images/noisy-images/9952.jpg
#   inflating: noisy-images/noisy-images/9953.jpg
#   inflating: noisy-images/noisy-images/9954.jpg
#   inflating: noisy-images/noisy-images/9955.jpg
#   inflating: noisy-images/noisy-images/9956.jpg
#   inflating: noisy-images/noisy-images/9957.jpg
#   inflating: noisy-images/noisy-images/9958.jpg
#   inflating: noisy-images/noisy-images/9959.jpg
#   inflating: noisy-images/noisy-images/9960.jpg
#   inflating: noisy-images/noisy-images/9961.jpg
#   inflating: noisy-images/noisy-images/9962.jpg
#   inflating: noisy-images/noisy-images/9963.jpg
#   inflating: noisy-images/noisy-images/9964.jpg
#   inflating: noisy-images/noisy-images/9966.jpg
#   inflating: noisy-images/noisy-images/9967.jpg
#   inflating: noisy-images/noisy-images/9968.jpg
#   inflating: noisy-images/noisy-images/9969.jpg
#   inflating: noisy-images/noisy-images/9970.jpg
#   inflating: noisy-images/noisy-images/9971.jpg
#   inflating: noisy-images/noisy-images/9972.jpg
#   inflating: noisy-images/noisy-images/9973.jpg
#   inflating: noisy-images/noisy-images/9974.jpg
#   inflating: noisy-images/noisy-images/9975.jpg
#   inflating: noisy-images/noisy-images/9976.jpg
#   inflating: noisy-images/noisy-images/9977.jpg
#   inflating: noisy-images/noisy-images/9978.jpg
#   inflating: noisy-images/noisy-images/9980.jpg
#   inflating: noisy-images/noisy-images/9981.jpg
#   inflating: noisy-images/noisy-images/9982.jpg
#   inflating: noisy-images/noisy-images/9983.jpg
#   inflating: noisy-images/noisy-images/9984.jpg
#   inflating: noisy-images/noisy-images/9985.jpg
#   inflating: noisy-images/noisy-images/9986.jpg
#   inflating: noisy-images/noisy-images/9987.jpg
#   inflating: noisy-images/noisy-images/9988.jpg
#   inflating: noisy-images/noisy-images/9989.jpg
#   inflating: noisy-images/noisy-images/9990.jpg
#   inflating: noisy-images/noisy-images/9991.jpg
#   inflating: noisy-images/noisy-images/9992.jpg
#   inflating: noisy-images/noisy-images/9993.jpg
#   inflating: noisy-images/noisy-images/9994.jpg
#   inflating: noisy-images/noisy-images/9995.jpg
#   inflating: noisy-images/noisy-images/9996.jpg
#   inflating: noisy-images/noisy-images/9997.jpg
#   inflating: noisy-images/noisy-images/9998.jpg
#   inflating: noisy-images/noisy-images/9999.jpg
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv
# noisy-images  sample_submission.csv  train.csv
# sample_data   test.csv		     uw-cs480-winter23.zip

# %% [markdown]
# # Required Libraries

# %%
# !pip install zeugma
# !pip install dill
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting zeugma
#   Downloading zeugma-0.49.tar.gz (9.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/dist-packages (from zeugma) (1.22.4)
# Requirement already satisfied: Cython>=0.27.3 in /usr/local/lib/python3.9/dist-packages (from zeugma) (0.29.34)
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.9/dist-packages (from zeugma) (1.5.3)
# Requirement already satisfied: gensim>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from zeugma) (4.3.1)
# Requirement already satisfied: scikit_learn>=0.19.1 in /usr/local/lib/python3.9/dist-packages (from zeugma) (1.2.2)
# Requirement already satisfied: tensorflow>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from zeugma) (2.12.0)
# Requirement already satisfied: keras>=2.1.3 in /usr/local/lib/python3.9/dist-packages (from zeugma) (2.12.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim>=3.5.0->zeugma) (6.3.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from gensim>=3.5.0->zeugma) (1.10.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.20.3->zeugma) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.20.3->zeugma) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit_learn>=0.19.1->zeugma) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit_learn>=0.19.1->zeugma) (1.2.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (0.4.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (67.6.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (4.5.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (3.8.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (2.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (23.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (1.6.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (2.12.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (0.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (1.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (0.32.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (1.53.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (23.3.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.5.0->zeugma) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow>=1.5.0->zeugma) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=1.5.0->zeugma) (0.0.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (2.17.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (3.4.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (6.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=1.5.0->zeugma) (3.2.2)
# Building wheels for collected packages: zeugma
#   Building wheel for zeugma (setup.py) ... done
#   Created wheel for zeugma: filename=zeugma-0.49-py3-none-any.whl size=8809 sha256=9432af0866ba2c1f9a243ae4ffd6b30bec33c9e88f78d1c6f6f45e214448ea05
#   Stored in directory: /root/.cache/pip/wheels/81/eb/a0/b3178c0a0fa7de13d140cc79f3106867f5c74540e2d66b85f7
# Successfully built zeugma
# Installing collected packages: zeugma
# Successfully installed zeugma-0.49
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.9 MB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.6

# %%
# %matplotlib inline

import os.path
import shutil
from google.colab import files
import dill

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

# used for preprocessing & defining models
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.base import clone
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

# for text embedding
from zeugma.embeddings import EmbeddingTransformer
glove = EmbeddingTransformer('glove')

# for combined text and categorical models
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier

# for images
from skimage import io
from tqdm import tqdm
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
import torchvision
from torchvision.transforms import ToTensor
import torchvision.transforms as transforms
import torch.nn.functional as F

# ensemble learning
from sklearn.ensemble import BaggingClassifier
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
import time
import math

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# # Part 1: Load Data

# %%
# define variables
cat_cols = ['gender', 'baseColour', 'season', 'usage']
text_cols = ['noisyTextDescription']
target = 'category'

# %%
def load_data(filename='train.csv'):
  df = pd.read_csv(filename, index_col='id')
  return df

# load train and test data
train_df = load_data(filename='train.csv')
test_df = load_data(filename='test.csv')

# split into X_train, y_train, X_val
X_train = train_df[cat_cols + text_cols]
y_train = train_df[target]
X_val = test_df

# %%
# define dictionaries used to encode classes into indices and vice versa
classes = train_df[target].unique()
class_to_idx = {c: id for id, c in enumerate(classes)}
idx_to_class = {id: c for id, c in enumerate(classes)}

# encode y_train into indices
y_train_transformed = np.vectorize(class_to_idx.get)(y_train)

# %% [markdown]
# # Part 2: Combine Text & Categorical Data
#
# - Categorical data: applied one-hot encoding.
# - Text data: computed normalized term frequency matrix of noisyTextDescription column.
#
# Concatenate the preprocessed categorical and text data to be fitted later.

# %%
def squeeze(x):
  return x.squeeze()

def toarray(x):
  return x.toarray()

# one-hot encode categorical columns
cat_pipeline = Pipeline(steps=[
    ('one-hot',OneHotEncoder())
])

# get normalized term frequency matrix of noisyTextDescription column
text_pipeline = Pipeline(steps=[
    ("squeeze", FunctionTransformer(squeeze)),
     ('vect', CountVectorizer(stop_words='english', strip_accents='unicode')),
     ('tfidf', TfidfTransformer(use_idf=False)),
     ("toarray", FunctionTransformer(toarray)),
])

# combined transformation on all feature columns
col_trans = ColumnTransformer(transformers=[
    ('cat_pipeline', cat_pipeline, cat_cols),
    ('text_pipeline', text_pipeline, text_cols),
    ],
    n_jobs=-1)

# %% [markdown]
# ## Model 1: LinearSVC

# %%
########## try with LinearSVC ##########
### base
clf = LinearSVC(max_iter=5)

clf_pipeline_LinearSVC = Pipeline(steps=[
    ('col_trans', col_trans),
    ('base', clf)
])

### bagging
estimator = clone(clf_pipeline_LinearSVC.steps[1][1])
bag_clf_pipeline_LinearSVC = Pipeline(steps=[
    ('col_trans', col_trans),
    ('bag', BaggingClassifier(estimator = estimator))
])
display(bag_clf_pipeline_LinearSVC)

# fit the bagged pipeline
bag_clf_pipeline_LinearSVC.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('col_trans',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('cat_pipeline',
#                                                   Pipeline(steps=[('one-hot',
#                                                                    OneHotEncoder())]),
#                                                   ['gender', 'baseColour',
#                                                    'season', 'usage']),
#                                                  ('text_pipeline',
#                                                   Pipeline(steps=[('squeeze',
#                                                                    FunctionTransformer(func=<function squeeze at 0x7feef5721550>)),
#                                                                   ('vect',
#                                                                    CountVectorizer(stop_words='english',
#                                                                                    strip_accents='unicode')),
#                                                                   ('tfidf',
#                                                                    TfidfTransformer(use_idf=False)),
#                                                                   ('toarray',
#                                                                    FunctionTransformer(func=<function toarray at 0x7feef5721a60>))]),
#                                                   ['noisyTextDescription'])])),
#                 ('bag', BaggingClassifier(estimator=LinearSVC(max_iter=5)))])
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Pipeline(steps=[('col_trans',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('cat_pipeline',
#                                                   Pipeline(steps=[('one-hot',
#                                                                    OneHotEncoder())]),
#                                                   ['gender', 'baseColour',
#                                                    'season', 'usage']),
#                                                  ('text_pipeline',
#                                                   Pipeline(steps=[('squeeze',
#                                                                    FunctionTransformer(func=<function squeeze at 0x7feef5721550>)),
#                                                                   ('vect',
#                                                                    CountVectorizer(stop_words='english',
#                                                                                    strip_accents='unicode')),
#                                                                   ('tfidf',
#                                                                    TfidfTransformer(use_idf=False)),
#                                                                   ('toarray',
#                                                                    FunctionTransformer(func=<function toarray at 0x7feef5721a60>))]),
#                                                   ['noisyTextDescription'])])),
#                 ('bag', BaggingClassifier(estimator=LinearSVC(max_iter=5)))])

# %% [markdown]
# ## Model 2: SGDClassifier

# %%
########## try with SGDClassifier ##########
### base
clf = SGDClassifier(loss='hinge', penalty='l2',
                           alpha=1e-4, max_iter=5, tol=None)

clf_pipeline_SGDClassifier = Pipeline(steps=[
    ('col_trans', col_trans),
    ('base', clf)
])

### bagging
estimator = clone(clf_pipeline_SGDClassifier.steps[1][1])
bag_clf_pipeline_SGDClassifier = Pipeline(steps=[
    ('col_trans', col_trans),
    ('bag', BaggingClassifier(estimator = estimator))
])
display(bag_clf_pipeline_SGDClassifier)

# fit the bagged pipeline
bag_clf_pipeline_SGDClassifier.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('col_trans',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('cat_pipeline',
#                                                   Pipeline(steps=[('one-hot',
#                                                                    OneHotEncoder())]),
#                                                   ['gender', 'baseColour',
#                                                    'season', 'usage']),
#                                                  ('text_pipeline',
#                                                   Pipeline(steps=[('squeeze',
#                                                                    FunctionTransformer(func=<function squeeze at 0x7feef5721550>)),
#                                                                   ('vect',
#                                                                    CountVectorizer(stop_words='english',
#                                                                                    strip_accents='unicode')),
#                                                                   ('tfidf',
#                                                                    TfidfTransformer(use_idf=False)),
#                                                                   ('toarray',
#                                                                    FunctionTransformer(func=<function toarray at 0x7feef5721a60>))]),
#                                                   ['noisyTextDescription'])])),
#                 ('bag',
#                  BaggingClassifier(estimator=SGDClassifier(max_iter=5,
#                                                            tol=None)))])
# Pipeline(steps=[('col_trans',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('cat_pipeline',
#                                                   Pipeline(steps=[('one-hot',
#                                                                    OneHotEncoder())]),
#                                                   ['gender', 'baseColour',
#                                                    'season', 'usage']),
#                                                  ('text_pipeline',
#                                                   Pipeline(steps=[('squeeze',
#                                                                    FunctionTransformer(func=<function squeeze at 0x7feef5721550>)),
#                                                                   ('vect',
#                                                                    CountVectorizer(stop_words='english',
#                                                                                    strip_accents='unicode')),
#                                                                   ('tfidf',
#                                                                    TfidfTransformer(use_idf=False)),
#                                                                   ('toarray',
#                                                                    FunctionTransformer(func=<function toarray at 0x7feef5721a60>))]),
#                                                   ['noisyTextDescription'])])),
#                 ('bag',
#                  BaggingClassifier(estimator=SGDClassifier(max_iter=5,
#                                                            tol=None)))])

# %%
# # uncomment and run this if you'd like to save the models
# # highly recommend saving in case colab crashes due to reaching RAM usage limit
# torch.save(obj = bag_clf_pipeline_LinearSVC, f = 'test_bag_clf_pipeline_LinearSVC.pkl', pickle_module=dill)
# torch.save(obj = bag_clf_pipeline_SGDClassifier, f = 'test_bag_clf_pipeline_SGDClassifier.pkl', pickle_module=dill)

# %%
# # call garbage collector if necessary
# import gc
# gc.collect()
# Out:
# 232

# %% [markdown]
# # Part 3: CNN Models

# %% [markdown]
# ## Part 3.0: Useful Functions & Classes

# %%
# script parameters
batch_size = 64
log_interval = 100

# %%
# define CustomDataset class
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, X_index, X, y = None, transform=None, return_extra_variables=True):
        self.X = X
        self.y = y
        self.root_dir = root_dir
        self.transform = transform
        self.X_index = X_index
        self.return_extra_variables = return_extra_variables

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        # image
        if torch.is_tensor(idx):
            idx = idx.tolist()
        img_name = os.path.join(self.root_dir, str(self.X_index[idx]) + '.jpg')
        image = io.imread(img_name)
        target = self.y[idx] if self.y is not None else 0 # simply put something

        if self.transform:
            image = self.transform(image)

        # data variable could contain one-hot encoded/embedded categorical data and/or
        # term frequency matrix of noisyTextDescription column
        data = torch.tensor(self.X[idx].copy())

        if self.return_extra_variables:
          return (image, data), target
        return image, target

# %%
def prepare_dataloaders(transform, X_train_index, X_val_index, X_train, y_train, X_val, y_val=None, 
                        batch_size=batch_size, root_dir='noisy-images/noisy-images', return_extra_variables=True):
  # load training set
  trainset = CustomDataset(root_dir=root_dir, X=X_train, y=y_train, transform=transform, X_index=X_train_index, 
                           return_extra_variables=return_extra_variables)
  train_dataloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

  # load test set
  testset = CustomDataset(root_dir=root_dir, X=X_val, y=y_val, transform=transform, X_index=X_val_index, 
                          return_extra_variables=return_extra_variables)
  test_dataloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

  return train_dataloader, test_dataloader

# calculate mean and standard deviation of dataset
def batch_mean_and_sd(loader):
    
    cnt = 0
    fst_moment = torch.empty(3)
    snd_moment = torch.empty(3)

    for train, _ in loader:
        images = train[0]
        b, c, h, w = images.shape
        nb_pixels = b * h * w
        sum_ = torch.sum(images, dim=[0, 2, 3])
        sum_of_square = torch.sum(images ** 2,
                                  dim=[0, 2, 3])
        fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
        snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)
        cnt += nb_pixels

    mean, std = fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)        
    return mean,std

# %%
# function to train CNN
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.train()
    train_loss, correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        y = y.to(device)
        if model.__class__.__name__ != 'CNN_deeper_dropout_v2':
          images = X[0].to(device)
          data = X[1].to(device)
          pred = model(images, data)
        else:
          X = X.to(device)
          pred = model(X)

        # Compute prediction error
        loss = loss_fn(pred, y)
        train_loss += loss.item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    average_train_loss = train_loss / num_batches
    accuracy = correct / size
    return accuracy, average_train_loss

# %%
# function to generate CNN predictions
def predict_images(dataloader, model):
    predictions = torch.Tensor([]).to(device)
    prob_predictions = torch.Tensor([]).to(device)
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for batch, (X, y) in enumerate(dataloader):
            y = y.to(device)
            if model.__class__.__name__ != 'CNN_deeper_dropout_v2':
              images = X[0].to(device)
              data = X[1].to(device)
              pred = model(images, data)
            else:
              X = X.to(device)
              pred = model(X)

            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            predictions = torch.cat((predictions, pred.argmax(1)))
            prob_predictions = torch.cat((prob_predictions, torch.exp(pred))) # get probabilities
    accuracy = correct / size
    return accuracy, predictions.cpu().numpy(), prob_predictions.cpu().numpy()

# %% [markdown]
# ## Part 3.1: Combine Images & Categorical Data

# %% [markdown]
# ### Method 1: One-hot encoding on categorical data
#
# - Images: transform to Tensor and normalize images using mean and std of whole train dataset.
# - Categorical data: apply one-hot encoding.

# %%
# one hot encoding pipeline
cat_pipeline_onehot = Pipeline(steps=[
    ('one-hot',OneHotEncoder(sparse_output = False, dtype = np.float32))
])
col_trans_onehot = ColumnTransformer(transformers=[
    ('cat_pipeline', cat_pipeline_onehot, cat_cols),
    ],
    remainder='drop',
    n_jobs=-1)

clf_pipeline_onehot = Pipeline(steps=[
    ('col_trans', col_trans_onehot)
])

# %%
clf_pipeline_onehot.fit(X_train)
X_train_onehot = clf_pipeline_onehot.transform(X_train)
X_val_onehot = clf_pipeline_onehot.transform(X_val)

# %% [markdown]
# Before normalizing:

# %%
# transform to Tensor
transform = transforms.Compose([
    transforms.ToTensor(),
    ])

train_dataloader_onehot, test_dataloader_onehot = prepare_dataloaders(X_train=X_train_onehot, y_train=y_train_transformed, 
                                                        X_val=X_val_onehot, X_train_index = X_train.index, X_val_index = X_val.index, 
                                                        transform=transform)

# %%
mean, std = batch_mean_and_sd(train_dataloader_onehot)
print("mean and std: \n", mean, std)
# Out:
# mean and std:
#  tensor([0.8189, 0.8041, 0.7972]) tensor([0.2229, 0.2339, 0.2368])

# %% [markdown]
# Use the above mean and standard deviation to normalize our dataset.
#
# After normalizing:

# %%
# define transformations
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize(mean, std),
    ])

train_dataloader_onehot, test_dataloader_onehot = prepare_dataloaders(X_train=X_train_onehot, y_train=y_train_transformed, 
                                                        X_val=X_val_onehot, X_train_index = X_train.index, X_val_index = X_val.index,
                                                         transform=transform)

# %% [markdown]
# ### Method 2: Categorical embeddings
#
# - Images: transform to Tensor and normalize images using mean and std of whole train dataset.
# - Categorical data: lowercase and concatenate the strings in all categorical columns before converting to embeddings using pretrained 25-dimensional GLoVe embeddings.

# %%
# Here glove is a sklearn transformer has the standard transform method that takes a list of sentences as input 
# and outputs a design matrix, just like Tfidftransformer. 
# You can get the resulting embeddings with:
# embeddings = glove.transform(['first sentence of the corpus', 'another sentence']) 
# and embeddings woud contain a 2 x N matrics, where N is the dimension of the chosen embedding. 
def embed_categorical_columns(x):
  cat_cols_lowercase = x[cat_cols].apply(lambda col: col.astype(str).str.lower())
  cat_cols_joined = cat_cols_lowercase.apply(" ".join, axis=1)
  embed_col = glove.transform(cat_cols_joined)
  return embed_col
  # return pd.DataFrame(embed_col, index=x.index)

clf_pipeline_embed = Pipeline(steps=[
    ('embed_categorical_columns', FunctionTransformer(embed_categorical_columns)),
])

# %%
clf_pipeline_embed.fit(X_train)
X_train_embed = clf_pipeline_embed.transform(X_train)
X_val_embed = clf_pipeline_embed.transform(X_val)

# %%
# define transformations
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize(mean, std),
    ])

train_dataloader_embed, test_dataloader_embed = prepare_dataloaders(X_train=X_train_embed, y_train=y_train_transformed, 
                                                        X_val=X_val_embed, X_train_index = X_train.index, X_val_index = X_val.index,
                                                        transform=transform)

# %% [markdown]
# ## Part 3.2: Images Only
#
# - Images: transform to Tensor and normalize images using mean and std of whole train dataset.

# %%
# transform to Tensor
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
    ])

train_dataloader_original, test_dataloader_original = prepare_dataloaders(X_train=X_train_embed, y_train=y_train_transformed, 
                                                        X_val=X_val_embed, X_train_index = X_train.index, X_val_index = X_val.index,
                                                        transform=transform,
                                                        return_extra_variables=False)

# %% [markdown]
# ## Part 3.3: Combine Images, Categorical & Text Data

# %% [markdown]
# ### Method 1: One-hot encoding on categorical data, TF on text data
#
# - Images: transform to Tensor and normalize images using mean and std of whole train dataset.
# - Categorical data: apply one-hot encoding.
# - Text data: compute normalized term frequency matrix of noisyTextDescription column.

# %%
def squeeze(x):
  return x.squeeze()

def toarray(x):
  return x.toarray()

def change_dtype(x):
  return x.astype('float32')

# default token pattern
text_pipeline = Pipeline(steps=[
    ("squeeze", FunctionTransformer(squeeze)),
     ('vect', CountVectorizer(stop_words='english', strip_accents='unicode')),
     ('tfidf', TfidfTransformer(use_idf=False)),
     ("toarray", FunctionTransformer(toarray)),
     ("change_dtype", FunctionTransformer(change_dtype)),
])

# one hot encoding pipeline
cat_pipeline_onehot = Pipeline(steps=[
    ('one-hot',OneHotEncoder(sparse_output = False, dtype = np.float32))
])
col_trans_all = ColumnTransformer(transformers=[
    ('cat_pipeline', cat_pipeline_onehot, cat_cols),
    ('text_pipeline', text_pipeline, text_cols),
    ],
    remainder='drop',
    n_jobs=-1)

clf_pipeline_all = Pipeline(steps=[
    ('col_trans', col_trans_all)
])

# %%
clf_pipeline_all.fit(X_train)
X_train_all = clf_pipeline_all.transform(X_train)
X_val_all = clf_pipeline_all.transform(X_val)

# %%
# define transformations
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize(mean, std),
    ])

train_dataloader_all, test_dataloader_all = prepare_dataloaders(X_train=X_train_all, y_train=y_train_transformed, 
                                                        X_val=X_val_all, X_train_index = X_train.index, X_val_index = X_val.index,
                                                        transform=transform)

# %% [markdown]
# ### Method 2: Categorical embeddings, TF on text data
#
# - Images: transform to Tensor and normalize images using mean and std of whole train dataset.
# - Categorical data: lowercase and concatenate the strings in all categorical columns before converting to embeddings using pretrained 25-dimensional GLoVe embeddings.
# - Text data: compute normalized term frequency matrix of noisyTextDescription column.

# %%
cat_pipeline_embed = Pipeline(steps=[
    ('embed_categorical_columns', FunctionTransformer(embed_categorical_columns)),
])

col_trans_all_embed = ColumnTransformer(transformers=[
    ('cat_pipeline', cat_pipeline_embed, cat_cols + text_cols), # use all columns since function takes in whole dataframe
    ('text_pipeline', text_pipeline, text_cols),
    ],
    remainder='drop',
    n_jobs=-1)

clf_pipeline_all_embed = Pipeline(steps=[
    ('col_trans', col_trans_all_embed)
])

# %%
clf_pipeline_all_embed.fit(X_train)
X_train_all_embed = clf_pipeline_all_embed.transform(X_train)
X_val_all_embed = clf_pipeline_all_embed.transform(X_val)

# %%
# define transformations
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize(mean, std),
    ])

train_dataloader_all_embed, test_dataloader_all_embed = prepare_dataloaders(X_train=X_train_all_embed, y_train=y_train_transformed, 
                                                        X_val=X_val_all_embed, X_train_index = X_train.index, X_val_index = X_val.index,
                                                        transform=transform)

# %% [markdown]
# ## Part 3.4: Model Data

# %%
#negative log likelihood loss
loss_fn = nn.NLLLoss()

# %% [markdown]
# ### Model 1: CNN with images and categorical embeddings

# %%
# Define model - hidden nodes = 1024, more blocks, added new pooling
class CNN_deeper_dropout_v4_add_cat_embed(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding='same')
        self.conv1b = nn.Conv2d(64, 64, 3, padding='same')
        self.conv2 = nn.Conv2d(64, 128, 3, padding='same')
        self.conv2b = nn.Conv2d(128, 128, 3, padding='same')
        self.pool = nn.MaxPool2d(2, 2)
        self.pool2 = nn.MaxPool2d((2,3), (2,3))
        self.fc1 = nn.Linear(128*5*10+25,1024)
        self.fc2 = nn.Linear(1024, 27)
        self.dropout1 = nn.Dropout(p=0.25)
        self.dropout2 = nn.Dropout(p=0.5)

    def forward(self, image, cat_embed):
        image = F.relu(self.conv1(image))
        image = F.relu(self.conv1b(image))
        image = self.pool(image)
        image = self.dropout1(image)

        image = F.relu(self.conv2(image))
        image = F.relu(self.conv2b(image))
        image = self.pool2(image)
        image = self.dropout1(image)

        image = F.relu(self.conv2b(image))
        image = F.relu(self.conv2b(image))
        image = self.pool(image)
        image = self.dropout1(image)

        x1 = torch.flatten(image, 1) # flatten all dimensions except batch
        x2 = cat_embed
        x = torch.cat((x1, x2), dim=1)
        
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.log_softmax(self.fc2(x), 1)
        return x

# %%
# define model and optimizer
model_deeper_dropout_v4_add_cat_embed = CNN_deeper_dropout_v4_add_cat_embed().to(device)
optimizer_deeper_dropout_v4_add_cat_embed = torch.optim.Adam(model_deeper_dropout_v4_add_cat_embed.parameters())


model_optimizer_dict = {
    'test_CNN_deeper_dropout_v4_add_cat_embed': (model_deeper_dropout_v4_add_cat_embed, 
                                                 optimizer_deeper_dropout_v4_add_cat_embed, 
                                                 train_dataloader_embed, 
                                                 test_dataloader_embed),
    }

# %%
best_epoch = 11 # best performing epoch

for model_type, model_optimizer_train_test_pair in model_optimizer_dict.items():
  model = model_optimizer_train_test_pair[0]
  optimizer = model_optimizer_train_test_pair[1]
  train_dataloader = model_optimizer_train_test_pair[2]
  test_dataloader = model_optimizer_train_test_pair[3]
  print(model_type)
  for t in tqdm(range(best_epoch)):
    # train
    train_accuracy, average_train_loss = train(train_dataloader, model, loss_fn, optimizer)
    print(f"Epoch {t+1}:\t Train accuracy: {100*train_accuracy:0.1f}%")
  print('\n')
  torch.save(model, '{}.pt'.format(model_type))
  # files.download('{}.pt'.format(model_type))
# Out:
# test_CNN_deeper_dropout_v4_add_cat_embed
#   9%|▉         | 1/11 [00:39<06:35, 39.54s/it]
# Epoch 1:	 Train accuracy: 56.3%
#  18%|█▊        | 2/11 [01:03<04:34, 30.46s/it]
# Epoch 2:	 Train accuracy: 74.6%
#  27%|██▋       | 3/11 [01:30<03:48, 28.61s/it]
# Epoch 3:	 Train accuracy: 78.1%
#  36%|███▋      | 4/11 [01:53<03:06, 26.60s/it]
# Epoch 4:	 Train accuracy: 79.9%
#  45%|████▌     | 5/11 [02:15<02:30, 25.04s/it]
# Epoch 5:	 Train accuracy: 81.3%
#  55%|█████▍    | 6/11 [02:39<02:02, 24.47s/it]
# Epoch 6:	 Train accuracy: 82.5%
#  64%|██████▎   | 7/11 [03:01<01:35, 23.83s/it]
# Epoch 7:	 Train accuracy: 83.1%
#  73%|███████▎  | 8/11 [03:24<01:10, 23.36s/it]
# Epoch 8:	 Train accuracy: 84.0%
#  82%|████████▏ | 9/11 [03:47<00:46, 23.31s/it]
# Epoch 9:	 Train accuracy: 84.3%
#  91%|█████████ | 10/11 [04:10<00:23, 23.22s/it]
# Epoch 10:	 Train accuracy: 84.9%
# 100%|██████████| 11/11 [04:32<00:00, 24.75s/it]
# Epoch 11:	 Train accuracy: 85.3%

# %% [markdown]
# ### Model 2: CNN with images and OHE categorical columns

# %%
# Define model - hidden nodes = 1024, more blocks, added new pooling
class CNN_deeper_dropout_v3_add_cat(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding='same')
        self.conv1b = nn.Conv2d(64, 64, 3, padding='same')
        self.conv2 = nn.Conv2d(64, 128, 3, padding='same')
        self.conv2b = nn.Conv2d(128, 128, 3, padding='same')
        self.pool = nn.MaxPool2d(2, 2)
        self.pool2 = nn.MaxPool2d((2,3), (2,3))
        self.fc1 = nn.Linear(128*5*10+(5+46+4+7),1024)
        self.fc2 = nn.Linear(1024, 27)
        self.dropout1 = nn.Dropout(p=0.25)
        self.dropout2 = nn.Dropout(p=0.5)

    def forward(self, image, cat_data):
        image = F.relu(self.conv1(image))
        image = F.relu(self.conv1b(image))
        image = self.pool(image)
        image = self.dropout1(image)

        image = F.relu(self.conv2(image))
        image = F.relu(self.conv2b(image))
        image = self.pool2(image)
        image = self.dropout1(image)

        image = F.relu(self.conv2b(image))
        image = F.relu(self.conv2b(image))
        image = self.pool(image)
        image = self.dropout1(image)

        x1 = torch.flatten(image, 1) # flatten all dimensions except batch
        x2 = cat_data
        x = torch.cat((x1, x2), dim=1)
        
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.log_softmax(self.fc2(x), 1)
        return x

# %%
# define model and optimizer
# define models
model_deeper_dropout_v3_add_cat = CNN_deeper_dropout_v3_add_cat().to(device)
optimizer_deeper_dropout_v3_add_cat = torch.optim.Adam(model_deeper_dropout_v3_add_cat.parameters())

model_optimizer_dict = {
    'test_CNN_deeper_dropout_v3_add_cat': (model_deeper_dropout_v3_add_cat, 
                                           optimizer_deeper_dropout_v3_add_cat, 
                                           train_dataloader_onehot, 
                                           test_dataloader_onehot),
    }

# %%
best_epoch = 7 # best performing epoch

for model_type, model_optimizer_train_test_pair in model_optimizer_dict.items():
  model = model_optimizer_train_test_pair[0]
  optimizer = model_optimizer_train_test_pair[1]
  train_dataloader = model_optimizer_train_test_pair[2]
  test_dataloader = model_optimizer_train_test_pair[3]
  print(model_type)
  for t in tqdm(range(best_epoch)):
    # train
    train_accuracy, average_train_loss = train(train_dataloader, model, loss_fn, optimizer)
    print(f"Epoch {t+1}:\t Train accuracy: {100*train_accuracy:0.1f}%")
  print('\n')
  torch.save(model, '{}.pt'.format(model_type))
  # files.download('{}.pt'.format(model_type))
# Out:
# test_CNN_deeper_dropout_v3_add_cat
#  14%|█▍        | 1/7 [00:20<02:02, 20.39s/it]
# Epoch 1:	 Train accuracy: 55.8%
#  29%|██▊       | 2/7 [00:39<01:39, 19.88s/it]
# Epoch 2:	 Train accuracy: 77.8%
#  43%|████▎     | 3/7 [00:59<01:19, 19.95s/it]
# Epoch 3:	 Train accuracy: 80.6%
#  57%|█████▋    | 4/7 [01:21<01:02, 20.70s/it]
# Epoch 4:	 Train accuracy: 82.3%
#  71%|███████▏  | 5/7 [01:41<00:40, 20.46s/it]
# Epoch 5:	 Train accuracy: 83.3%
#  86%|████████▌ | 6/7 [02:03<00:21, 21.04s/it]
# Epoch 6:	 Train accuracy: 84.3%
# 100%|██████████| 7/7 [02:25<00:00, 20.74s/it]
# Epoch 7:	 Train accuracy: 85.1%

# %% [markdown]
# ### Model 3: CNN with images only

# %%
# Define model - hidden nodes = 1024, more blocks, added new pooling
class CNN_deeper_dropout_v2(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding='same')
        self.conv1b = nn.Conv2d(64, 64, 3, padding='same')
        self.conv2 = nn.Conv2d(64, 128, 3, padding='same')
        self.conv2b = nn.Conv2d(128, 128, 3, padding='same')
        self.pool = nn.MaxPool2d(2, 2)
        self.pool2 = nn.MaxPool2d((2,3), (2,3))
        self.fc1 = nn.Linear(128*5*10,1024)
        self.fc2 = nn.Linear(1024, 27)
        self.dropout1 = nn.Dropout(p=0.25)
        self.dropout2 = nn.Dropout(p=0.5)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv1b(x))
        x = self.pool(x)
        x = self.dropout1(x)

        x = F.relu(self.conv2(x))
        x = F.relu(self.conv2b(x))
        x = self.pool2(x)
        x = self.dropout1(x)

        x = F.relu(self.conv2b(x))
        x = F.relu(self.conv2b(x))
        x = self.pool(x)
        x = self.dropout1(x)

        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.log_softmax(self.fc2(x), 1)
        return x

# %%
# define model and optimizer
model_deeper_dropout_v2 = CNN_deeper_dropout_v2().to(device)
optimizer_deeper_dropout_v2 = torch.optim.Adam(model_deeper_dropout_v2.parameters())

model_optimizer_dict = {
    'test_CNN_deeper_dropout_v2': (model_deeper_dropout_v2, 
                                   optimizer_deeper_dropout_v2, 
                                   train_dataloader_original, 
                                   test_dataloader_original),
    }

# %%
best_epoch = 7 # best performing epoch

for model_type, model_optimizer_train_test_pair in model_optimizer_dict.items():
  model = model_optimizer_train_test_pair[0]
  optimizer = model_optimizer_train_test_pair[1]
  train_dataloader = model_optimizer_train_test_pair[2]
  test_dataloader = model_optimizer_train_test_pair[3]
  print(model_type)
  for t in tqdm(range(best_epoch)):
    # train
    train_accuracy, average_train_loss = train(train_dataloader, model, loss_fn, optimizer)
    print(f"Epoch {t+1}:\t Train accuracy: {100*train_accuracy:0.1f}%")
  print('\n')
  torch.save(model, '{}.pt'.format(model_type))
  # files.download('{}.pt'.format(model_type))
# Out:
# test_CNN_deeper_dropout_v2
#  14%|█▍        | 1/7 [00:22<02:17, 22.97s/it]
# Epoch 1:	 Train accuracy: 59.6%
#  29%|██▊       | 2/7 [00:44<01:49, 21.93s/it]
# Epoch 2:	 Train accuracy: 75.4%
#  43%|████▎     | 3/7 [01:03<01:22, 20.73s/it]
# Epoch 3:	 Train accuracy: 78.0%
#  57%|█████▋    | 4/7 [01:23<01:01, 20.38s/it]
# Epoch 4:	 Train accuracy: 79.5%
#  71%|███████▏  | 5/7 [01:43<00:40, 20.19s/it]
# Epoch 5:	 Train accuracy: 80.5%
#  86%|████████▌ | 6/7 [02:03<00:20, 20.18s/it]
# Epoch 6:	 Train accuracy: 81.4%
# 100%|██████████| 7/7 [02:26<00:00, 20.86s/it]
# Epoch 7:	 Train accuracy: 81.8%

# %% [markdown]
# ### Model 4: CNN with images, OHE categorical columns, and TF on text data

# %%
# Define model - hidden nodes = 1024, more blocks, added new pooling
class test_CNN_deeper_dropout_v5_add_cat_text(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding='same')
        self.conv1b = nn.Conv2d(64, 64, 3, padding='same')
        self.conv2 = nn.Conv2d(64, 128, 3, padding='same')
        self.conv2b = nn.Conv2d(128, 128, 3, padding='same')
        self.pool = nn.MaxPool2d(2, 2)
        self.pool2 = nn.MaxPool2d((2,3), (2,3))
        self.fc1 = nn.Linear(128*5*10+8499,1024)
        self.fc2 = nn.Linear(1024, 27)
        self.dropout1 = nn.Dropout(p=0.25)
        self.dropout2 = nn.Dropout(p=0.5)

    def forward(self, image, cat_data):
        image = F.relu(self.conv1(image))
        image = F.relu(self.conv1b(image))
        image = self.pool(image)
        image = self.dropout1(image)

        image = F.relu(self.conv2(image))
        image = F.relu(self.conv2b(image))
        image = self.pool2(image)
        image = self.dropout1(image)

        image = F.relu(self.conv2b(image))
        image = F.relu(self.conv2b(image))
        image = self.pool(image)
        image = self.dropout1(image)

        x1 = torch.flatten(image, 1) # flatten all dimensions except batch
        x2 = cat_data
        x = torch.cat((x1, x2), dim=1)
        
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.log_softmax(self.fc2(x), 1)
        return x

# %%
# define model and optimizer
model_deeper_dropout_v5_add_cat_text = test_CNN_deeper_dropout_v5_add_cat_text().to(device)
optimizer_deeper_dropout_v5_add_cat_text = torch.optim.Adam(model_deeper_dropout_v5_add_cat_text.parameters())

model_optimizer_dict = {
    'test_CNN_deeper_dropout_v5_add_cat_text': (model_deeper_dropout_v5_add_cat_text, 
                                                optimizer_deeper_dropout_v5_add_cat_text, 
                                                train_dataloader_all, 
                                                test_dataloader_all),
    }

# %%
best_epoch = 7 # best performing epoch

for model_type, model_optimizer_train_test_pair in model_optimizer_dict.items():
  model = model_optimizer_train_test_pair[0]
  optimizer = model_optimizer_train_test_pair[1]
  train_dataloader = model_optimizer_train_test_pair[2]
  test_dataloader = model_optimizer_train_test_pair[3]
  print(model_type)
  for t in tqdm(range(best_epoch)):
    # train
    train_accuracy, average_train_loss = train(train_dataloader, model, loss_fn, optimizer)
    print(f"Epoch {t+1}:\t Train accuracy: {100*train_accuracy:0.1f}%")
  print('\n')
  torch.save(model, '{}.pt'.format(model_type))
  # files.download('{}.pt'.format(model_type))
# Out:
# test_CNN_deeper_dropout_v5_add_cat_text
#  14%|█▍        | 1/7 [00:22<02:14, 22.41s/it]
# Epoch 1:	 Train accuracy: 62.2%
#  29%|██▊       | 2/7 [00:44<01:51, 22.37s/it]
# Epoch 2:	 Train accuracy: 86.7%
#  43%|████▎     | 3/7 [01:05<01:27, 21.81s/it]
# Epoch 3:	 Train accuracy: 90.9%
#  57%|█████▋    | 4/7 [01:27<01:05, 21.76s/it]
# Epoch 4:	 Train accuracy: 93.0%
#  71%|███████▏  | 5/7 [01:48<00:42, 21.38s/it]
# Epoch 5:	 Train accuracy: 94.5%
#  86%|████████▌ | 6/7 [02:11<00:21, 21.95s/it]
# Epoch 6:	 Train accuracy: 95.8%
# 100%|██████████| 7/7 [02:34<00:00, 22.01s/it]
# Epoch 7:	 Train accuracy: 96.7%

# %% [markdown]
# ### Model 5: CNN with images, categorical embeddings, and TF on text data

# %%
# Define model - hidden nodes = 1024, more blocks, added new pooling
class test_CNN_deeper_dropout_v6_add_cat_embed_text(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding='same')
        self.conv1b = nn.Conv2d(64, 64, 3, padding='same')
        self.conv2 = nn.Conv2d(64, 128, 3, padding='same')
        self.conv2b = nn.Conv2d(128, 128, 3, padding='same')
        self.pool = nn.MaxPool2d(2, 2)
        self.pool2 = nn.MaxPool2d((2,3), (2,3))
        self.fc1 = nn.Linear(128*5*10+8462,1024)
        self.fc2 = nn.Linear(1024, 27)
        self.dropout1 = nn.Dropout(p=0.25)
        self.dropout2 = nn.Dropout(p=0.5)

    def forward(self, image, cat_data):
        image = F.relu(self.conv1(image))
        image = F.relu(self.conv1b(image))
        image = self.pool(image)
        image = self.dropout1(image)

        image = F.relu(self.conv2(image))
        image = F.relu(self.conv2b(image))
        image = self.pool2(image)
        image = self.dropout1(image)

        image = F.relu(self.conv2b(image))
        image = F.relu(self.conv2b(image))
        image = self.pool(image)
        image = self.dropout1(image)

        x1 = torch.flatten(image, 1) # flatten all dimensions except batch
        x2 = cat_data
        x = torch.cat((x1, x2), dim=1)
        
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.log_softmax(self.fc2(x), 1)
        return x

# %%
# define model and optimizer
model_deeper_dropout_v6_add_cat_embed_text = test_CNN_deeper_dropout_v6_add_cat_embed_text().to(device)
optimizer_deeper_dropout_v6_add_cat_embed_text = torch.optim.Adam(model_deeper_dropout_v6_add_cat_embed_text.parameters())

model_optimizer_dict = {
    'test_CNN_deeper_dropout_v6_add_cat_embed_text': (model_deeper_dropout_v6_add_cat_embed_text, 
                                                      optimizer_deeper_dropout_v6_add_cat_embed_text, 
                                                      train_dataloader_all_embed, 
                                                      test_dataloader_all_embed),
    }

# %%
best_epoch = 7 # best performing epoch

for model_type, model_optimizer_train_test_pair in model_optimizer_dict.items():
  model = model_optimizer_train_test_pair[0]
  optimizer = model_optimizer_train_test_pair[1]
  train_dataloader = model_optimizer_train_test_pair[2]
  test_dataloader = model_optimizer_train_test_pair[3]
  print(model_type)
  for t in tqdm(range(best_epoch)):
    # train
    train_accuracy, average_train_loss = train(train_dataloader, model, loss_fn, optimizer)
    print(f"Epoch {t+1}:\t Train accuracy: {100*train_accuracy:0.1f}%")
  print('\n')
  torch.save(model, '{}.pt'.format(model_type))
  # files.download('{}.pt'.format(model_type))
# Out:
# test_CNN_deeper_dropout_v6_add_cat_embed_text
#  14%|█▍        | 1/7 [00:21<02:06, 21.12s/it]
# Epoch 1:	 Train accuracy: 60.5%
#  29%|██▊       | 2/7 [00:41<01:43, 20.79s/it]
# Epoch 2:	 Train accuracy: 82.2%
#  43%|████▎     | 3/7 [01:04<01:26, 21.74s/it]
# Epoch 3:	 Train accuracy: 88.0%
#  57%|█████▋    | 4/7 [01:25<01:04, 21.51s/it]
# Epoch 4:	 Train accuracy: 90.4%
#  71%|███████▏  | 5/7 [01:46<00:42, 21.25s/it]
# Epoch 5:	 Train accuracy: 92.3%
#  86%|████████▌ | 6/7 [02:07<00:21, 21.33s/it]
# Epoch 6:	 Train accuracy: 93.9%
# 100%|██████████| 7/7 [02:28<00:00, 21.22s/it]
# Epoch 7:	 Train accuracy: 94.9%

# %% [markdown]
# # Part 4: Weighted Majority Vote

# %%
def get_predictions(models, X_test=X_val):
  predictions = np.array([])
  for item in models:
    if isinstance(item, tuple):
      model = item[0]
      if 'CNN' in model.__class__.__name__:
        test = item[1]
        _, prediction, _ = predict_images(dataloader=test, model=model)
      elif isinstance(item[1], tuple):
        Xtest, _ = item[1][0], item[1][1]
        prediction = model.predict(Xtest)
      else:
        test = item[1]
        prediction = model.predict(test)
    
    else:
      model = item
      prediction = model.predict(X_test)
      
    # flatten prediction
    prediction = prediction.flatten()
    
    # convert back to string
    if prediction.dtype not in (np.dtype('<U24'), np.dtype(object)):
      prediction = np.vectorize(idx_to_class.get)(prediction.astype(int))
      # prediction = le.inverse_transform(prediction.astype(int))

    # update predictions
    predictions = np.vstack((predictions, prediction)) if len(predictions) != 0 else prediction

  return predictions

def calculate_weights(accuracies, n_models_per_type = [1,1,1,1,1]):
  div_weights_by = np.array(n_models_per_type).copy()
  weights = accuracies.copy()

  start = 0
  end = 0
  for i in range(len(div_weights_by)):
      start = sum(div_weights_by[:i])
      end = sum(div_weights_by[:i+1])
      weights[start:end] /= div_weights_by[i]

  return weights

def majority_vote(predictions, vote_type='hard', weights=None):
  predictions_df = pd.DataFrame(np.transpose(predictions))

  if vote_type =='hard':
    return predictions_df.mode(axis=1)[0] # if there are ties, take the category from left to right
  elif vote_type == 'soft':
    weights = weights / sum(weights) # normalize
    weights = weights.flatten()
    predictions_df_enc = pd.DataFrame(np.transpose(predictions)).replace(class_to_idx)
    predictions_df_enc = predictions_df_enc.apply(lambda x: np.bincount(x, weights=weights).argmax(), axis=1)
    predictions_df = predictions_df_enc.replace(idx_to_class)
    return predictions_df

# %%
def format_predictions(predictions, index, target=target):
  predictions_df = final_predictions.to_frame()
  predictions_df.index = index
  predictions_df.columns = [target]
  return predictions_df

def download_predictions(predictions_df, filename):
  predictions_df.to_csv('{}.csv'.format(filename))
  files.download('{}.csv'.format(filename))

# %%
###### uncomment and load models if necessary #####
### Image Models
model_deeper_dropout_v2 = torch.load('test_CNN_deeper_dropout_v2.pt', map_location=device)

### Combined Cat and Text Models
bag_clf_pipeline_LinearSVC = torch.load('test_bag_clf_pipeline_LinearSVC.pkl', pickle_module=dill, map_location=device)
bag_clf_pipeline_SGDClassifier = torch.load('test_bag_clf_pipeline_SGDClassifier.pkl', pickle_module=dill, map_location=device)

### Combined Cat and Image Models
model_deeper_dropout_v3_add_cat = torch.load('test_CNN_deeper_dropout_v3_add_cat.pt', map_location=device)
model_deeper_dropout_v4_add_cat_embed = torch.load('test_CNN_deeper_dropout_v4_add_cat_embed.pt', map_location=device)

# ### Combined Cat, Text and Image Models
model_deeper_dropout_v5_add_cat_text = torch.load('test_CNN_deeper_dropout_v5_add_cat_text.pt', map_location=device)
model_deeper_dropout_v6_add_cat_embed_text = torch.load('test_CNN_deeper_dropout_v6_add_cat_embed_text.pt', map_location=device)

# %%
cat_models = [
]

image_models = [
    (model_deeper_dropout_v2, test_dataloader_original),
]

cat_and_text_combined_models = [
    bag_clf_pipeline_LinearSVC, 
    bag_clf_pipeline_SGDClassifier,
]

cat_and_image_combined_models = [
    (model_deeper_dropout_v3_add_cat, test_dataloader_onehot),
    (model_deeper_dropout_v4_add_cat_embed, test_dataloader_embed),
]

cat_and_text_and_image_combined_models = [
    (model_deeper_dropout_v5_add_cat_text, test_dataloader_all),
    (model_deeper_dropout_v6_add_cat_embed_text, test_dataloader_all_embed),
]

all_models = cat_models + image_models + cat_and_text_combined_models + cat_and_image_combined_models + cat_and_text_and_image_combined_models

# %% [markdown]
# ---

# %%
# if Colab keeps crashing on this line of code due to reaching RAM usage limit, please ignore this line of code
# and instead. Read the text block below for more instructions.
predictions = get_predictions(all_models, X_test=X_val)

# %% [markdown]
# Colab has a high risk of crashing due to LinearSVC and SGDClassifier. If it continues to do so, only run the following sections:
#
# - Upload files in Google Colab (if necessary)
# - Required Libraries (you can skip !pip install if no need)
# - Part 1: Load Data
# - First 2 code blocks in Part 4: Weighted Majority Vote
# - Only call torch.load on LinearSVC and SGDClassifier
# - Run the initialization of `cat_and_text_combined_models` only.
#
# Finally, run `predictions3 = get_predictions(cat_and_text_combined_models, X_test=X_val)` and `np.save`,
#
# After that, you can go ahead and run all the previous code blocks and continue running the notebook.
#
# If it happens to crash again, at least `np.load` will make it easier. You can also download the `predictions.npy` files and upload them in case Colab crashes.

# %%
# # if Colab keeps crashing on this line of code due to reaching RAM usage limit, please uncomment and run this.
# predictions3 = get_predictions(cat_and_text_combined_models, X_test=X_val)
# np.save('predictions3.npy', predictions3)

# %%
# # if Colab keeps crashing on this line of code due to reaching RAM usage limit, please uncomment and run this.
# predictions2 = get_predictions(image_models, X_test=X_val)
# np.save('predictions2.npy', predictions2)

# %%
# # if Colab keeps crashing on this line of code due to reaching RAM usage limit, please uncomment and run this.
# predictions4 = get_predictions(cat_and_image_combined_models, X_test=X_val)
# np.save('predictions4.npy', predictions4)

# %%
# # if Colab keeps crashing on this line of code due to reaching RAM usage limit, please uncomment and run this.
# predictions5 = get_predictions(cat_and_text_and_image_combined_models, X_test=X_val)
# np.save('predictions5.npy', predictions5)

# %%
# # if Colab keeps crashing on this line of code due to reaching RAM usage limit, please uncomment and run this.
# predictions2 = np.load('predictions2.npy', allow_pickle=True)
# predictions3 = np.load('predictions3.npy', allow_pickle=True)
# predictions4 = np.load('predictions4.npy', allow_pickle=True)
# predictions5 = np.load('predictions5.npy', allow_pickle=True)

# %%
# predictions = np.vstack((predictions2, predictions3, predictions4, predictions5))

# %%
# predictions
# Out:
# array([['Bottomwear', 'Shoes', 'Wallets', ..., 'Wallets', 'Topwear',
#         'Topwear'],
#        ['Bottomwear', 'Sandal', 'Bags', ..., 'Wallets', 'Topwear',
#         'Topwear'],
#        ['Bottomwear', 'Sandal', 'Bags', ..., 'Wallets', 'Topwear',
#         'Topwear'],
#        ...,
#        ['Bottomwear', 'Sandal', 'Wallets', ..., 'Wallets', 'Topwear',
#         'Topwear'],
#        ['Bottomwear', 'Sandal', 'Bags', ..., 'Wallets', 'Topwear',
#         'Topwear'],
#        ['Bottomwear', 'Sandal', 'Bags', ..., 'Wallets', 'Topwear',
#         'Topwear']], dtype=object)

# %% [markdown]
# ---

# %%
val_accuracies = np.array([
    [0.80617718], 
    [0.82800074],
    [0.82282227],
    [0.84131681],
    [0.83650823],
    [0.90290364],
    [0.89069724]
    ])

weights = calculate_weights(val_accuracies)
final_predictions = majority_vote(predictions, vote_type='soft', weights=weights)

# %%
final_predictions
# Out:
# 0        Bottomwear
# 1            Sandal
# 2              Bags
# 3             Shoes
# 4           Wallets
#             ...
# 21623       Topwear
# 21624         Shoes
# 21625       Wallets
# 21626       Topwear
# 21627       Topwear
# Length: 21628, dtype: object

# %% [markdown]
# # Part 5: Download Predictions

# %%
predictions_df = format_predictions(predictions=final_predictions, index=X_val.index)
download_predictions(predictions_df=predictions_df, filename='final_submission')
